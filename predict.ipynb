# %%
import pandas as pd

# %%
df = pd.read_csv("nba_games_raw.csv", index_col=0)

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              43.7         206.0         104.0       GSW        111
# 1              34.6         162.0         104.0       CHI         97
# 2              29.0         138.0         105.0       CLE         95
# 3              38.9         201.0         120.0       NOP         95
# 4              23.6         132.0         104.0       DET        106
# ...             ...           ...           ...       ...        ...
# 17767          36.3         133.0         112.0       GSW        107
# 17768          94.4         300.0         112.0       BOS         94
# 17769          36.2         222.0         107.0       GSW        104
# 17770          31.5         186.0         111.0       GSW        103
# 17771          42.6         141.0         126.0       BOS         90
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27  False       0
# 1             1    2016  2015-10-27  False       1
# 2             0    2016  2015-10-27   True       1
# 3             0    2016  2015-10-27   True       1
# 4             0    2016  2015-10-27  False       1
# ...         ...     ...         ...    ...     ...
# 17767         0    2022  2022-06-10  False       0
# 17768         0    2022  2022-06-13   True       1
# 17769         1    2022  2022-06-13  False       0
# 17770         0    2022  2022-06-16  False       2
# 17771         1    2022  2022-06-16   True       2
#
# [17772 rows x 142 columns]

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)

# %%
def add_target(team):
    team["target"] = team["won"].shift(-1)
    return team

df = df.groupby("team", group_keys=False).apply(add_target)

# %%
df[df["team"] == "WAS"]
# Out:
#           mp    fg    fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 27     240.0  33.0   84.0  0.393   7.0  28.0  0.250  15.0  25.0  0.600  ...
# 51     240.0  35.0   68.0  0.515  12.0  21.0  0.571  36.0  44.0  0.818  ...
# 75     240.0  38.0   90.0  0.422   6.0  22.0  0.273  28.0  33.0  0.848  ...
# 131    240.0  42.0   87.0  0.483   8.0  23.0  0.348  10.0  14.0  0.714  ...
# 154    240.0  36.0   88.0  0.409   8.0  25.0  0.320  18.0  23.0  0.783  ...
# ...      ...   ...    ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17464  240.0  38.0   82.0  0.463   8.0  21.0  0.381  18.0  20.0  0.900  ...
# 17496  240.0  56.0  101.0  0.554  13.0  30.0  0.433   7.0  14.0  0.500  ...
# 17508  240.0  42.0   86.0  0.488  10.0  35.0  0.286   9.0  11.0  0.818  ...
# 17546  240.0  35.0   69.0  0.507   9.0  28.0  0.321  13.0  17.0  0.765  ...
# 17583  240.0  42.0   94.0  0.447   8.0  23.0  0.348  16.0  26.0  0.615  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 27             25.2         134.0          98.0       ORL         87
# 51             32.4         138.0         122.0       MIL        113
# 75             28.7         153.0         108.0       NYK        117
# 131            30.0         160.0         109.0       SAS         99
# 154            41.6         146.0         103.0       BOS        118
# ...             ...           ...           ...       ...        ...
# 17464          34.4         245.0         116.0       BOS        144
# 17496          32.8         168.0         132.0       MIN        114
# 17508          60.2         159.0         114.0       ATL        118
# 17546          35.5         135.0         104.0       NYK        114
# 17583          37.3         161.0         118.0       CHO        124
#
#        home_opp  season        date    won  target
# 27            1    2016  2015-10-28   True    True
# 51            1    2016  2015-10-30   True   False
# 75            0    2016  2015-10-31  False    True
# 131           0    2016  2015-11-04   True   False
# 154           1    2016  2015-11-06  False   False
# ...         ...     ...         ...    ...     ...
# 17464         1    2022  2022-04-03  False    True
# 17496         1    2022  2022-04-05   True   False
# 17508         1    2022  2022-04-06  False   False
# 17546         0    2022  2022-04-08  False   False
# 17583         1    2022  2022-04-10  False     NaN
#
# [580 rows x 142 columns]

# %%
df["target"][pd.isnull(df["target"])] = 2
# Out:
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_68449/1618397414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["target"][pd.isnull(df["target"])] = 2

# %%
df["target"] = df["target"].astype(int, errors="ignore")

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              43.7         206.0         104.0       GSW        111
# 1              34.6         162.0         104.0       CHI         97
# 2              29.0         138.0         105.0       CLE         95
# 3              38.9         201.0         120.0       NOP         95
# 4              23.6         132.0         104.0       DET        106
# ...             ...           ...           ...       ...        ...
# 17767          36.3         133.0         112.0       GSW        107
# 17768          94.4         300.0         112.0       BOS         94
# 17769          36.2         222.0         107.0       GSW        104
# 17770          31.5         186.0         111.0       GSW        103
# 17771          42.6         141.0         126.0       BOS         90
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27  False       0
# 1             1    2016  2015-10-27  False       1
# 2             0    2016  2015-10-27   True       1
# 3             0    2016  2015-10-27   True       1
# 4             0    2016  2015-10-27  False       1
# ...         ...     ...         ...    ...     ...
# 17767         0    2022  2022-06-10  False       0
# 17768         0    2022  2022-06-13   True       1
# 17769         1    2022  2022-06-13  False       0
# 17770         0    2022  2022-06-16  False       2
# 17771         1    2022  2022-06-16   True       2
#
# [17772 rows x 142 columns]

# %%
df["won"].value_counts()
# Out:
# won
# False    8886
# True     8886
# Name: count, dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 1    8872
# 0    8870
# 2      30
# Name: count, dtype: int64

# %%
nulls = pd.isnull(df)

# %%
nulls = nulls.sum()

# %%
nulls = nulls[nulls > 0]

# %%
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=142)

# %%
df = df[valid_columns].copy()

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              43.7         206.0         104.0       GSW        111
# 1              34.6         162.0         104.0       CHI         97
# 2              29.0         138.0         105.0       CLE         95
# 3              38.9         201.0         120.0       NOP         95
# 4              23.6         132.0         104.0       DET        106
# ...             ...           ...           ...       ...        ...
# 17767          36.3         133.0         112.0       GSW        107
# 17768          94.4         300.0         112.0       BOS         94
# 17769          36.2         222.0         107.0       GSW        104
# 17770          31.5         186.0         111.0       GSW        103
# 17771          42.6         141.0         126.0       BOS         90
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27  False       0
# 1             1    2016  2015-10-27  False       1
# 2             0    2016  2015-10-27   True       1
# 3             0    2016  2015-10-27   True       1
# 4             0    2016  2015-10-27  False       1
# ...         ...     ...         ...    ...     ...
# 17767         0    2022  2022-06-10  False       0
# 17768         0    2022  2022-06-13   True       1
# 17769         1    2022  2022-06-13  False       0
# 17770         0    2022  2022-06-16  False       2
# 17771         1    2022  2022-06-16   True       2
#
# [17772 rows x 142 columns]

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha=1)
split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr, n_features_to_select=30, direction="forward", cv=split)

# %%
removed_columns = ["season", "date", "target", "team", "team_opp"]

# %%
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# 1      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 2      0.0  0.409091  0.397059  0.373206  0.241379  0.227273  0.437055
# 3      0.0  0.500000  0.529412  0.377990  0.310345  0.393939  0.356295
# 4      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  usg%_max_opp  ortg_max_opp  \
# 0      0.418605  0.412698  0.654609  ...      0.277279      0.554502
# 1      0.209302  0.253968  0.519253  ...      0.160462      0.345972
# 2      0.348837  0.349206  0.645274  ...      0.088575      0.232227
# 3      0.441860  0.333333  0.893816  ...      0.215661      0.530806
# 4      0.255814  0.222222  0.766628  ...      0.019255      0.203791
# ...         ...       ...       ...  ...           ...           ...
# 17767  0.302326  0.285714  0.693116  ...      0.182285      0.208531
# 17768  0.279070  0.222222  0.844807  ...      0.928113      1.000000
# 17769  0.465116  0.476190  0.623104  ...      0.181001      0.630332
# 17770  0.232558  0.174603  0.903151  ...      0.120668      0.459716
# 17771  0.162791  0.111111  1.000000  ...      0.263158      0.246445
#
#        drtg_max_opp  team_opp  total_opp  home_opp  season        date  won  \
# 0          0.317647       GSW   0.451923       1.0    2016  2015-10-27  0.0
# 1          0.317647       CHI   0.317308       1.0    2016  2015-10-27  0.0
# 2          0.329412       CLE   0.298077       0.0    2016  2015-10-27  1.0
# 3          0.505882       NOP   0.298077       0.0    2016  2015-10-27  1.0
# 4          0.317647       DET   0.403846       0.0    2016  2015-10-27  0.0
# ...             ...       ...        ...       ...     ...         ...  ...
# 17767      0.411765       GSW   0.413462       0.0    2022  2022-06-10  0.0
# 17768      0.411765       BOS   0.288462       0.0    2022  2022-06-13  1.0
# 17769      0.352941       GSW   0.384615       1.0    2022  2022-06-13  0.0
# 17770      0.400000       GSW   0.375000       0.0    2022  2022-06-16  0.0
# 17771      0.576471       BOS   0.250000       1.0    2022  2022-06-16  1.0
#
#        target
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 17767       0
# 17768       1
# 17769       0
# 17770       2
# 17771       2
#
# [17772 rows x 142 columns]

# %%
sfs.fit(df[selected_columns], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['ft%',
#  'efg%',
#  'orb%',
#  'trb%',
#  'usg%',
#  'ortg',
#  '3p_max',
#  'pts_max',
#  'ts%_max',
#  'efg%_max',
#  'drb%_max',
#  'trb%_max',
#  'tov%_max',
#  'ortg_max',
#  'fg_opp',
#  'ft%_opp',
#  'blk_opp',
#  'drb%_opp',
#  'trb%_opp',
#  'blk%_opp',
#  'usg%_opp',
#  'drtg_opp',
#  'ft%_max_opp',
#  'tov_max_opp',
#  '3par_max_opp',
#  'ast%_max_opp',
#  'stl%_max_opp',
#  'usg%_max_opp',
#  'drtg_max_opp',
#  'won']

# %%
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []
    
    seasons = sorted(df["season"].unique())
    
    for i in range(start, len(seasons), step):
        season = seasons[i]
        
        train = data[data["season"] < season]
        test = data[data["season"] == season]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
predictions
# Out:
#        actual  prediction
# 5250        1           1
# 5251        1           0
# 5252        0           0
# 5253        1           1
# 5254        0           1
# ...       ...         ...
# 17767       0           0
# 17768       1           1
# 17769       0           1
# 17770       2           1
# 17771       2           1
#
# [12522 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score


predictions = predictions[predictions["actual"] != 2]
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5432276657060519

# %%
df.groupby("home").apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# home
# 0.0    0.428314
# 1.0    0.571686
# dtype: float64

# %%
df_rolling = df[list(selected_columns) + ["team", "season"]]

# %%
df_rolling
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# 1      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 2      0.0  0.409091  0.397059  0.373206  0.241379  0.227273  0.437055
# 3      0.0  0.500000  0.529412  0.377990  0.310345  0.393939  0.356295
# 4      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  blk%_max_opp  tov%_max_opp  \
# 0      0.418605  0.412698  0.654609  ...         0.079      0.679245
# 1      0.209302  0.253968  0.519253  ...         0.140      0.509434
# 2      0.348837  0.349206  0.645274  ...         0.185      0.270440
# 3      0.441860  0.333333  0.893816  ...         0.063      0.344864
# 4      0.255814  0.222222  0.766628  ...         0.047      0.300839
# ...         ...       ...       ...  ...           ...           ...
# 17767  0.302326  0.285714  0.693116  ...         0.103      0.401468
# 17768  0.279070  0.222222  0.844807  ...         0.124      0.423480
# 17769  0.465116  0.476190  0.623104  ...         0.076      0.300839
# 17770  0.232558  0.174603  0.903151  ...         0.063      0.300839
# 17771  0.162791  0.111111  1.000000  ...         0.160      1.000000
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  total_opp  home_opp  won  \
# 0          0.277279      0.554502      0.317647   0.451923       1.0  0.0
# 1          0.160462      0.345972      0.317647   0.317308       1.0  0.0
# 2          0.088575      0.232227      0.329412   0.298077       0.0  1.0
# 3          0.215661      0.530806      0.505882   0.298077       0.0  1.0
# 4          0.019255      0.203791      0.317647   0.403846       0.0  0.0
# ...             ...           ...           ...        ...       ...  ...
# 17767      0.182285      0.208531      0.411765   0.413462       0.0  0.0
# 17768      0.928113      1.000000      0.411765   0.288462       0.0  1.0
# 17769      0.181001      0.630332      0.352941   0.384615       1.0  0.0
# 17770      0.120668      0.459716      0.400000   0.375000       0.0  0.0
# 17771      0.263158      0.246445      0.576471   0.250000       1.0  1.0
#
#        team  season
# 0       NOP    2016
# 1       CLE    2016
# 2       CHI    2016
# 3       GSW    2016
# 4       ATL    2016
# ...     ...     ...
# 17767   BOS    2022
# 17768   GSW    2022
# 17769   BOS    2022
# 17770   BOS    2022
# 17771   GSW    2022
#
# [17772 rows x 139 columns]

# %%
def find_team_averages(team):
    rolling = team[selected_columns].rolling(10).mean()
    return rolling

df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)

# %%
df_rolling
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.381818  0.292647  0.428230  0.468966  0.477273  0.448100
# 17768  0.0  0.502273  0.364706  0.517703  0.455172  0.481818  0.440736
# 17769  0.0  0.354545  0.279412  0.404545  0.437931  0.465152  0.429572
# 17770  0.0  0.354545  0.294118  0.389952  0.434483  0.459091  0.431710
# 17771  0.0  0.484091  0.379412  0.482297  0.486207  0.507576  0.448812
#
#              ft       fta       ft%  ...  ast%_max_opp  stl%_max_opp  \
# 0           NaN       NaN       NaN  ...           NaN           NaN
# 1           NaN       NaN       NaN  ...           NaN           NaN
# 2           NaN       NaN       NaN  ...           NaN           NaN
# 3           NaN       NaN       NaN  ...           NaN           NaN
# 4           NaN       NaN       NaN  ...           NaN           NaN
# ...         ...       ...       ...  ...           ...           ...
# 17767  0.434884  0.373016  0.764177  ...      0.373394        0.0570
# 17768  0.320930  0.282540  0.757993  ...      0.546101        0.0716
# 17769  0.434884  0.385714  0.736639  ...      0.384060        0.0591
# 17770  0.406977  0.357143  0.754142  ...      0.393693        0.0572
# 17771  0.316279  0.269841  0.801750  ...      0.475803        0.0656
#
#        blk%_max_opp  tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  \
# 0               NaN           NaN           NaN           NaN           NaN
# 1               NaN           NaN           NaN           NaN           NaN
# 2               NaN           NaN           NaN           NaN           NaN
# 3               NaN           NaN           NaN           NaN           NaN
# 4               NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 17767        0.1113      0.471908      0.170603      0.431754      0.522353
# 17768        0.1171      0.374109      0.321566      0.642654      0.564706
# 17769        0.1113      0.483229      0.174711      0.438863      0.483529
# 17770        0.1111      0.483229      0.172144      0.460190      0.472941
# 17771        0.1152      0.444025      0.308601      0.628910      0.568235
#
#        total_opp  home_opp  won
# 0            NaN       NaN  NaN
# 1            NaN       NaN  NaN
# 2            NaN       NaN  NaN
# 3            NaN       NaN  NaN
# 4            NaN       NaN  NaN
# ...          ...       ...  ...
# 17767   0.348077       0.5  0.6
# 17768   0.392308       0.4  0.7
# 17769   0.350000       0.5  0.5
# 17770   0.344231       0.5  0.5
# 17771   0.395192       0.5  0.7
#
# [17772 rows x 137 columns]

# %%
rolling_cols = [f"{col}_10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols

df = pd.concat([df, df_rolling], axis=1)

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# 1      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 2      0.0  0.409091  0.397059  0.373206  0.241379  0.227273  0.437055
# 3      0.0  0.500000  0.529412  0.377990  0.310345  0.393939  0.356295
# 4      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  ast%_max_opp_10  stl%_max_opp_10  \
# 0      0.418605  0.412698  0.654609  ...              NaN              NaN
# 1      0.209302  0.253968  0.519253  ...              NaN              NaN
# 2      0.348837  0.349206  0.645274  ...              NaN              NaN
# 3      0.441860  0.333333  0.893816  ...              NaN              NaN
# 4      0.255814  0.222222  0.766628  ...              NaN              NaN
# ...         ...       ...       ...  ...              ...              ...
# 17767  0.302326  0.285714  0.693116  ...         0.373394           0.0570
# 17768  0.279070  0.222222  0.844807  ...         0.546101           0.0716
# 17769  0.465116  0.476190  0.623104  ...         0.384060           0.0591
# 17770  0.232558  0.174603  0.903151  ...         0.393693           0.0572
# 17771  0.162791  0.111111  1.000000  ...         0.475803           0.0656
#
#        blk%_max_opp_10  tov%_max_opp_10  usg%_max_opp_10  ortg_max_opp_10  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 17767           0.1113         0.471908         0.170603         0.431754
# 17768           0.1171         0.374109         0.321566         0.642654
# 17769           0.1113         0.483229         0.174711         0.438863
# 17770           0.1111         0.483229         0.172144         0.460190
# 17771           0.1152         0.444025         0.308601         0.628910
#
#        drtg_max_opp_10  total_opp_10  home_opp_10  won_10
# 0                  NaN           NaN          NaN     NaN
# 1                  NaN           NaN          NaN     NaN
# 2                  NaN           NaN          NaN     NaN
# 3                  NaN           NaN          NaN     NaN
# 4                  NaN           NaN          NaN     NaN
# ...                ...           ...          ...     ...
# 17767         0.522353      0.348077          0.5     0.6
# 17768         0.564706      0.392308          0.4     0.7
# 17769         0.483529      0.350000          0.5     0.5
# 17770         0.472941      0.344231          0.5     0.5
# 17771         0.568235      0.395192          0.5     0.7
#
# [17772 rows x 279 columns]

# %%
df.to_csv("nba_games_rolling.csv")

# %%
df = df.dropna()

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

df["home_next"] = add_col(df, "home")
df["team_opp_next"] = add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")
# Out:
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_68449/1688004556.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["home_next"] = add_col(df, "home")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_68449/1688004556.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["home_next"] = add_col(df, "home")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_68449/1688004556.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["team_opp_next"] = add_col(df, "team_opp")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_68449/1688004556.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["team_opp_next"] = add_col(df, "team_opp")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_68449/1688004556.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["date_next"] = add_col(df, "date")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_68449/1688004556.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["date_next"] = add_col(df, "date")

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 230    0.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 246    0.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 260    0.0  0.477273  0.500000  0.375598  0.379310  0.348485  0.483373
# 261    0.0  0.386364  0.235294  0.490431  0.206897  0.242424  0.356295
# 262    0.0  0.340909  0.250000  0.413876  0.310345  0.257576  0.509501
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  tov%_max_opp_10  usg%_max_opp_10  \
# 230    0.255814  0.238095  0.708285  ...         0.413522         0.124134
# 246    0.325581  0.238095  0.927655  ...         0.469497         0.219641
# 260    0.441860  0.396825  0.730455  ...         0.437212         0.124904
# 261    0.325581  0.301587  0.708285  ...         0.409119         0.134531
# 262    0.511628  0.412698  0.827305  ...         0.380294         0.273427
# ...         ...       ...       ...  ...              ...              ...
# 17767  0.302326  0.285714  0.693116  ...         0.471908         0.170603
# 17768  0.279070  0.222222  0.844807  ...         0.374109         0.321566
# 17769  0.465116  0.476190  0.623104  ...         0.483229         0.174711
# 17770  0.232558  0.174603  0.903151  ...         0.483229         0.172144
# 17771  0.162791  0.111111  1.000000  ...         0.444025         0.308601
#
#        ortg_max_opp_10  drtg_max_opp_10  total_opp_10  home_opp_10  won_10  \
# 230           0.361611         0.449412      0.347115          0.4     0.8
# 246           0.394787         0.531765      0.324038          0.5     1.0
# 260           0.404739         0.408235      0.428846          0.2     0.3
# 261           0.363507         0.452941      0.347115          0.5     0.8
# 262           0.270616         0.478824      0.308654          0.6     0.7
# ...                ...              ...           ...          ...     ...
# 17767         0.431754         0.522353      0.348077          0.5     0.6
# 17768         0.642654         0.564706      0.392308          0.4     0.7
# 17769         0.438863         0.483529      0.350000          0.5     0.5
# 17770         0.460190         0.472941      0.344231          0.5     0.5
# 17771         0.628910         0.568235      0.395192          0.5     0.7
#
#        home_next  team_opp_next   date_next
# 230          0.0            BOS  2015-11-13
# 246          1.0            BRK  2015-11-14
# 260          1.0            TOR  2015-11-15
# 261          1.0            UTA  2015-11-15
# 262          0.0            SAC  2015-11-15
# ...          ...            ...         ...
# 17767        0.0            GSW  2022-06-13
# 17768        0.0            BOS  2022-06-16
# 17769        1.0            GSW  2022-06-16
# 17770        NaN           None        None
# 17771        NaN           None        None
#
# [15882 rows x 282 columns]

# %%
df = df.copy()

# %%
full = df.merge(
    df[rolling_cols + ["team_opp_next", "date_next", "team"]], 
    left_on=["team", "date_next"], 
    right_on=["team_opp_next", "date_next"]
)

# %%
full
# Out:
#          mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.00  0.477273  0.500000  0.375598  0.379310  0.348485  0.483373
# 1      0.00  0.340909  0.250000  0.413876  0.310345  0.257576  0.509501
# 2      0.00  0.545455  0.426471  0.511962  0.275862  0.363636  0.339667
# 3      0.00  0.318182  0.323529  0.318182  0.275862  0.272727  0.432304
# 4      0.25  0.500000  0.558824  0.356459  0.068966  0.212121  0.131829
# ...     ...       ...       ...       ...       ...       ...       ...
# 15769  0.00  0.545455  0.426471  0.511962  0.448276  0.469697  0.440618
# 15770  0.00  0.477273  0.455882  0.409091  0.517241  0.590909  0.414489
# 15771  0.00  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 15772  0.00  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 15773  0.00  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
#
#              ft       fta       ft%  ...  blk%_max_opp_10_y  \
# 0      0.441860  0.396825  0.730455  ...             0.1072
# 1      0.511628  0.412698  0.827305  ...             0.1032
# 2      0.348837  0.317460  0.722287  ...             0.1826
# 3      0.186047  0.158730  0.787631  ...             0.0839
# 4      0.325581  0.238095  0.927655  ...             0.0842
# ...         ...       ...       ...  ...                ...
# 15769  0.372093  0.365079  0.659277  ...             0.1170
# 15770  0.255814  0.222222  0.766628  ...             0.1113
# 15771  0.302326  0.285714  0.693116  ...             0.1147
# 15772  0.279070  0.222222  0.844807  ...             0.1113
# 15773  0.465116  0.476190  0.623104  ...             0.1171
#
#        tov%_max_opp_10_y  usg%_max_opp_10_y  ortg_max_opp_10_y  \
# 0               0.380294           0.273427           0.270616
# 1               0.437212           0.124904           0.404739
# 2               0.427568           0.258280           0.514218
# 3               0.310377           0.127086           0.312796
# 4               0.421593           0.133504           0.345498
# ...                  ...                ...                ...
# 15769           0.457128           0.235173           0.562085
# 15770           0.471908           0.170603           0.431754
# 15771           0.431761           0.242875           0.567773
# 15772           0.483229           0.174711           0.438863
# 15773           0.374109           0.321566           0.642654
#
#        drtg_max_opp_10_y  total_opp_10_y  home_opp_10_y  won_10_y  \
# 0               0.478824        0.308654            0.6       0.7
# 1               0.408235        0.428846            0.2       0.3
# 2               0.335294        0.390385            0.5       0.0
# 3               0.410588        0.353846            0.5       0.6
# 4               0.454118        0.343269            0.4       0.7
# ...                  ...             ...            ...       ...
# 15769           0.552941        0.429808            0.4       0.6
# 15770           0.522353        0.348077            0.5       0.6
# 15771           0.575294        0.394231            0.4       0.7
# 15772           0.483529        0.350000            0.5       0.5
# 15773           0.564706        0.392308            0.4       0.7
#
#        team_opp_next_y  team_y
# 0                  SAC     TOR
# 1                  TOR     SAC
# 2                  DAL     PHI
# 3                  PHI     DAL
# 4                  BRK     ATL
# ...                ...     ...
# 15769              BOS     GSW
# 15770              GSW     BOS
# 15771              BOS     GSW
# 15772              GSW     BOS
# 15773              BOS     GSW
#
# [15774 rows x 421 columns]

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next", "season", "won"]]
# Out:
#       team_x team_opp_next_x team_y team_opp_next_y   date_next  season  won
# 0        SAC             TOR    TOR             SAC  2015-11-15    2016  1.0
# 1        TOR             SAC    SAC             TOR  2015-11-15    2016  1.0
# 2        DAL             PHI    PHI             DAL  2015-11-16    2016  1.0
# 3        PHI             DAL    DAL             PHI  2015-11-16    2016  0.0
# 4        BRK             ATL    ATL             BRK  2015-11-17    2016  0.0
# ...      ...             ...    ...             ...         ...     ...  ...
# 15769    BOS             GSW    GSW             BOS  2022-06-10    2022  1.0
# 15770    GSW             BOS    BOS             GSW  2022-06-13    2022  1.0
# 15771    BOS             GSW    GSW             BOS  2022-06-13    2022  0.0
# 15772    GSW             BOS    BOS             GSW  2022-06-16    2022  1.0
# 15773    BOS             GSW    GSW             BOS  2022-06-16    2022  0.0
#
# [15774 rows x 7 columns]

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns + ["won"]

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]

# %%
sfs.fit(full[selected_columns], full["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['fta',
#  'usg%',
#  'ft%_max',
#  'drb_max',
#  'efg%_max',
#  'trb%_max',
#  'pf_opp',
#  'usg%_opp',
#  'blk_max_opp',
#  'ftr_max_opp',
#  'ast%_max_opp',
#  'ast_10_x',
#  'usg%_10_x',
#  'ft%_max_10_x',
#  'ts%_max_10_x',
#  'ftr_opp_10_x',
#  'usg%_opp_10_x',
#  'drb_max_opp_10_x',
#  'ftr_max_opp_10_x',
#  'won_10_x',
#  'home_next',
#  'orb%_10_y',
#  'usg%_10_y',
#  '+/-_max_10_y',
#  'efg%_max_10_y',
#  'pf_opp_10_y',
#  'efg%_opp_10_y',
#  'usg%_opp_10_y',
#  '+/-_max_opp_10_y',
#  'won_10_y']

# %%
predictions = backtest(full, rr, predictors)

# %%
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.6322429485446517

# %%
predictions
# Out:
#        actual  prediction
# 4677        1           1
# 4678        1           0
# 4679        1           1
# 4680        1           1
# 4681        1           1
# ...       ...         ...
# 15769       0           1
# 15770       1           1
# 15771       0           0
# 15772       1           1
# 15773       0           0
#
# [11097 rows x 2 columns]

# %%
full[selected_columns]
# Out:
#          mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.00  0.477273  0.500000  0.375598  0.379310  0.348485  0.483373
# 1      0.00  0.340909  0.250000  0.413876  0.310345  0.257576  0.509501
# 2      0.00  0.545455  0.426471  0.511962  0.275862  0.363636  0.339667
# 3      0.00  0.318182  0.323529  0.318182  0.275862  0.272727  0.432304
# 4      0.25  0.500000  0.558824  0.356459  0.068966  0.212121  0.131829
# ...     ...       ...       ...       ...       ...       ...       ...
# 15769  0.00  0.545455  0.426471  0.511962  0.448276  0.469697  0.440618
# 15770  0.00  0.477273  0.455882  0.409091  0.517241  0.590909  0.414489
# 15771  0.00  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 15772  0.00  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 15773  0.00  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
#
#              ft       fta       ft%  ...  ast%_max_opp_10_y  \
# 0      0.441860  0.396825  0.730455  ...           0.458257
# 1      0.511628  0.412698  0.827305  ...           0.331537
# 2      0.348837  0.317460  0.722287  ...           0.533142
# 3      0.186047  0.158730  0.787631  ...           0.341743
# 4      0.325581  0.238095  0.927655  ...           0.321560
# ...         ...       ...       ...  ...                ...
# 15769  0.372093  0.365079  0.659277  ...           0.504472
# 15770  0.255814  0.222222  0.766628  ...           0.373394
# 15771  0.302326  0.285714  0.693116  ...           0.470528
# 15772  0.279070  0.222222  0.844807  ...           0.384060
# 15773  0.465116  0.476190  0.623104  ...           0.546101
#
#        stl%_max_opp_10_y  blk%_max_opp_10_y  tov%_max_opp_10_y  \
# 0                 0.0699             0.1072           0.380294
# 1                 0.0657             0.1032           0.437212
# 2                 0.0549             0.1826           0.427568
# 3                 0.0574             0.0839           0.310377
# 4                 0.0632             0.0842           0.421593
# ...                  ...                ...                ...
# 15769             0.0745             0.1170           0.457128
# 15770             0.0570             0.1113           0.471908
# 15771             0.0737             0.1147           0.431761
# 15772             0.0591             0.1113           0.483229
# 15773             0.0716             0.1171           0.374109
#
#        usg%_max_opp_10_y  ortg_max_opp_10_y  drtg_max_opp_10_y  \
# 0               0.273427           0.270616           0.478824
# 1               0.124904           0.404739           0.408235
# 2               0.258280           0.514218           0.335294
# 3               0.127086           0.312796           0.410588
# 4               0.133504           0.345498           0.454118
# ...                  ...                ...                ...
# 15769           0.235173           0.562085           0.552941
# 15770           0.170603           0.431754           0.522353
# 15771           0.242875           0.567773           0.575294
# 15772           0.174711           0.438863           0.483529
# 15773           0.321566           0.642654           0.564706
#
#        total_opp_10_y  home_opp_10_y  won_10_y
# 0            0.308654            0.6       0.7
# 1            0.428846            0.2       0.3
# 2            0.390385            0.5       0.0
# 3            0.353846            0.5       0.6
# 4            0.343269            0.4       0.7
# ...               ...            ...       ...
# 15769        0.429808            0.4       0.6
# 15770        0.348077            0.5       0.6
# 15771        0.394231            0.4       0.7
# 15772        0.350000            0.5       0.5
# 15773        0.392308            0.4       0.7
#
# [15774 rows x 411 columns]
