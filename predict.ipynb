# %%
import pandas as pd

# %%
df = pd.read_csv("nba_updated_games.csv", index_col=0)

# %%
df
# Out:
#           mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  38.0  72.0  0.528  16.0  37.0  0.432  18.0  21.0  ...
# 1      240.0  240.0  40.0  84.0  0.476  14.0  39.0  0.359  13.0  15.0  ...
# 2      240.0  240.0  41.0  78.0  0.526   8.0  24.0  0.333  15.0  19.0  ...
# 3      240.0  240.0  29.0  74.0  0.392  13.0  38.0  0.342  19.0  26.0  ...
# 4      240.0  240.0  39.0  81.0  0.481   6.0  20.0  0.300  14.0  18.0  ...
# ...      ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 21701  240.0  240.0  43.0  92.0  0.467  12.0  34.0  0.353  12.0  19.0  ...
# 21702  240.0  240.0  41.0  85.0  0.482   9.0  26.0  0.346  26.0  30.0  ...
# 21703  240.0  240.0  33.0  85.0  0.388  12.0  44.0  0.273  28.0  34.0  ...
# 21704  240.0  240.0  42.0  82.0  0.512  12.0  27.0  0.444  12.0  19.0  ...
# 21705  240.0  240.0  44.0  83.0  0.530  13.0  39.0  0.333  20.0  27.0  ...
#
#        tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0              26.2          26.8         155.0         123.0       MIA
# 1              41.0          37.3         160.0         121.0       POR
# 2              28.6          41.1         250.0         125.0       DAL
# 3              12.6          33.0         183.0         110.0       CLE
# 4              22.8          29.0         178.0         111.0       DAL
# ...             ...           ...           ...           ...       ...
# 21701          51.5          33.0         200.0         112.0       MIN
# 21702          27.7          27.1         150.0         126.0       MIA
# 21703          51.5          36.2         141.0         114.0       BOS
# 21704          53.2          28.0         146.0         126.0       TOR
# 21705          25.0          34.3         195.0         136.0       CHI
#
#        total_opp  home_opp  season        date    won
# 0            107         1    2023  2022-11-07   True
# 1            110         0    2023  2022-11-07  False
# 2             90         1    2023  2022-12-14   True
# 3            105         0    2023  2022-12-14  False
# 4             95         1    2016  2015-12-09   True
# ...          ...       ...     ...         ...    ...
# 21701        117         0    2024  2023-11-10  False
# 21702        106         1    2020  2020-09-19   True
# 21703        117         0    2020  2020-09-19  False
# 21704        121         1    2024  2023-11-24  False
# 21705        108         0    2024  2023-11-24   True
#
# [21706 rows x 150 columns]

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)

# %%
def add_target(team):
    team["target"] = team["won"].shift(-1)
    return team

df = df.groupby("team", group_keys=False).apply(add_target)

# %%
df[df["team"] == "WAS"]
# Out:
#           mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 30     240.0  240.0  33.0   84.0  0.393   7.0  28.0  0.250  15.0  25.0  ...
# 60     240.0  240.0  35.0   68.0  0.515  12.0  21.0  0.571  36.0  44.0  ...
# 72     240.0  240.0  38.0   90.0  0.422   6.0  22.0  0.273  28.0  33.0  ...
# 128    240.0  240.0  42.0   87.0  0.483   8.0  23.0  0.348  10.0  14.0  ...
# 163    240.0  240.0  36.0   88.0  0.409   8.0  25.0  0.320  18.0  23.0  ...
# ...      ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 21569  240.0  240.0  47.0   97.0  0.485  12.0  32.0  0.375  21.0  26.0  ...
# 21602  240.0  240.0  44.0   95.0  0.463  19.0  41.0  0.463  10.0  11.0  ...
# 21635  240.0  240.0  41.0   90.0  0.456  10.0  31.0  0.323  17.0  22.0  ...
# 21664  240.0  240.0  49.0  103.0  0.476   9.0  29.0  0.310  20.0  23.0  ...
# 21673  240.0  240.0  39.0   91.0  0.429   8.0  27.0  0.296  18.0  22.0  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 30             25.2         134.0          98.0       ORL         87
# 60             32.4         138.0         122.0       MIL        113
# 72             28.7         153.0         108.0       NYK        117
# 128            30.0         160.0         109.0       SAS         99
# 163            41.6         146.0         103.0       BOS        118
# ...             ...           ...           ...       ...        ...
# 21569          26.2         127.0         128.0       ATL         99
# 21602          33.5         171.0         127.0       DET        129
# 21635          40.2         200.0         113.0       NYK        113
# 21664          40.4         182.0         128.0       SAS        131
# 21673          33.3         176.0         116.0       DEN        113
#
#        home_opp  season        date    won  target
# 30            1    2016  2015-10-28   True    True
# 60            1    2016  2015-10-30   True   False
# 72            0    2016  2015-10-31  False    True
# 128           0    2016  2015-11-04   True   False
# 163           1    2016  2015-11-06  False   False
# ...         ...     ...         ...    ...     ...
# 21569         1    2024  2024-01-13   True   False
# 21602         0    2024  2024-01-15  False   False
# 21635         1    2024  2024-01-18  False   False
# 21664         0    2024  2024-01-20  False   False
# 21673         0    2024  2024-01-21  False     NaN
#
# [704 rows x 151 columns]

# %%
df["target"][pd.isnull(df["target"])] = 2
# Out:
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_58359/1618397414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["target"][pd.isnull(df["target"])] = 2

# %%
df["target"] = df["target"].astype(int, errors="ignore")

# %%
df
# Out:
#           mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  ...
# 1      240.0  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  ...
# 2      240.0  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  ...
# 3      240.0  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  ...
# 4      240.0  240.0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  ...
# ...      ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 21701  240.0  240.0  42.0  95.0  0.442  15.0  42.0  0.357   4.0   5.0  ...
# 21702  240.0  240.0  43.0  92.0  0.467  12.0  36.0  0.333  26.0  32.0  ...
# 21703  240.0  240.0  44.0  88.0  0.500  11.0  33.0  0.333  15.0  17.0  ...
# 21704  240.0  240.0  43.0  89.0  0.483   7.0  23.0  0.304  18.0  28.0  ...
# 21705  240.0  240.0  43.0  87.0  0.494   5.0  21.0  0.238  18.0  21.0  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              38.9         201.0         120.0       NOP         95
# 1              43.7         206.0         104.0       GSW        111
# 2              34.6         162.0         104.0       CHI         97
# 3              29.0         138.0         105.0       CLE         95
# 4              33.8         258.0         121.0       ATL         94
# ...             ...           ...           ...       ...        ...
# 21701          33.8         173.0         120.0       NYK        108
# 21702          50.0         225.0         121.0       NOP        153
# 21703          32.1         237.0         126.0       IND        109
# 21704          32.9         142.0         115.0       POR        109
# 21705          36.7         164.0         119.0       DEN        114
#
#        home_opp  season        date    won  target
# 0             0    2016  2015-10-27   True       1
# 1             1    2016  2015-10-27  False       0
# 2             1    2016  2015-10-27  False       1
# 3             0    2016  2015-10-27   True       1
# 4             1    2016  2015-10-27   True       1
# ...         ...     ...         ...    ...     ...
# 21701         0    2024  2024-01-23  False       2
# 21702         1    2024  2024-01-23  False       2
# 21703         1    2024  2024-01-23   True       2
# 21704         0    2024  2024-01-23   True       2
# 21705         0    2024  2024-01-23  False       2
#
# [21706 rows x 151 columns]

# %%
df["won"].value_counts()
# Out:
# won
# True     10853
# False    10853
# Name: count, dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 1    10839
# 0    10837
# 2       30
# Name: count, dtype: int64

# %%
nulls = pd.isnull(df)

# %%
nulls = nulls.sum()

# %%
nulls = nulls[nulls > 0]

# %%
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'mp.1', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=143)

# %%
df = df[valid_columns].copy()

# %%
df
# Out:
#           mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  ...
# 1      240.0  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  ...
# 2      240.0  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  ...
# 3      240.0  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  ...
# 4      240.0  240.0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  ...
# ...      ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 21701  240.0  240.0  42.0  95.0  0.442  15.0  42.0  0.357   4.0   5.0  ...
# 21702  240.0  240.0  43.0  92.0  0.467  12.0  36.0  0.333  26.0  32.0  ...
# 21703  240.0  240.0  44.0  88.0  0.500  11.0  33.0  0.333  15.0  17.0  ...
# 21704  240.0  240.0  43.0  89.0  0.483   7.0  23.0  0.304  18.0  28.0  ...
# 21705  240.0  240.0  43.0  87.0  0.494   5.0  21.0  0.238  18.0  21.0  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              38.9         201.0         120.0       NOP         95
# 1              43.7         206.0         104.0       GSW        111
# 2              34.6         162.0         104.0       CHI         97
# 3              29.0         138.0         105.0       CLE         95
# 4              33.8         258.0         121.0       ATL         94
# ...             ...           ...           ...       ...        ...
# 21701          33.8         173.0         120.0       NYK        108
# 21702          50.0         225.0         121.0       NOP        153
# 21703          32.1         237.0         126.0       IND        109
# 21704          32.9         142.0         115.0       POR        109
# 21705          36.7         164.0         119.0       DEN        114
#
#        home_opp  season        date    won  target
# 0             0    2016  2015-10-27   True       1
# 1             1    2016  2015-10-27  False       0
# 2             1    2016  2015-10-27  False       1
# 3             0    2016  2015-10-27   True       1
# 4             1    2016  2015-10-27   True       1
# ...         ...     ...         ...    ...     ...
# 21701         0    2024  2024-01-23  False       2
# 21702         1    2024  2024-01-23  False       2
# 21703         1    2024  2024-01-23   True       2
# 21704         0    2024  2024-01-23   True       2
# 21705         0    2024  2024-01-23  False       2
#
# [21706 rows x 143 columns]

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha=1)
split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr, n_features_to_select=30, direction="forward", cv=split)

# %%
removed_columns = ["season", "date", "target", "team", "team_opp"]

# %%
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
df
# Out:
#         mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0   0.0  0.478261  0.529412  0.377990  0.310345  0.393939  0.356295
# 1      0.0   0.0  0.347826  0.338235  0.366029  0.206897  0.212121  0.395487
# 2      0.0   0.0  0.413043  0.500000  0.322967  0.310345  0.378788  0.368171
# 3      0.0   0.0  0.391304  0.397059  0.373206  0.241379  0.227273  0.437055
# 4      0.0   0.0  0.391304  0.529412  0.277512  0.413793  0.378788  0.491686
# ...    ...   ...       ...       ...       ...       ...       ...       ...
# 21701  0.0   0.0  0.500000  0.514706  0.413876  0.517241  0.575758  0.423990
# 21702  0.0   0.0  0.521739  0.470588  0.473684  0.413793  0.484848  0.395487
# 21703  0.0   0.0  0.543478  0.411765  0.552632  0.379310  0.439394  0.395487
# 21704  0.0   0.0  0.521739  0.426471  0.511962  0.241379  0.287879  0.361045
# 21705  0.0   0.0  0.521739  0.397059  0.538278  0.172414  0.257576  0.282660
#
#              ft       fta  ...  usg%_max_opp  ortg_max_opp  drtg_max_opp  \
# 0      0.441860  0.333333  ...      0.216667      0.530806      0.505882
# 1      0.418605  0.412698  ...      0.278205      0.554502      0.317647
# 2      0.209302  0.253968  ...      0.161538      0.345972      0.317647
# 3      0.348837  0.349206  ...      0.089744      0.232227      0.329412
# 4      0.441860  0.396825  ...      0.151282      0.800948      0.517647
# ...         ...       ...  ...           ...           ...           ...
# 21701  0.069767  0.063492  ...      0.151282      0.398104      0.505882
# 21702  0.581395  0.492063  ...      0.358974      0.644550      0.517647
# 21703  0.325581  0.253968  ...      0.129487      0.701422      0.576471
# 21704  0.395349  0.428571  ...      0.139744      0.251185      0.447059
# 21705  0.395349  0.317460  ...      0.188462      0.355450      0.494118
#
#        team_opp  total_opp  home_opp  season        date  won  target
# 0           NOP   0.276786       0.0    2016  2015-10-27  1.0       1
# 1           GSW   0.419643       1.0    2016  2015-10-27  0.0       0
# 2           CHI   0.294643       1.0    2016  2015-10-27  0.0       1
# 3           CLE   0.276786       0.0    2016  2015-10-27  1.0       1
# 4           ATL   0.267857       1.0    2016  2015-10-27  1.0       1
# ...         ...        ...       ...     ...         ...  ...     ...
# 21701       NYK   0.392857       0.0    2024  2024-01-23  0.0       2
# 21702       NOP   0.794643       1.0    2024  2024-01-23  0.0       2
# 21703       IND   0.401786       1.0    2024  2024-01-23  1.0       2
# 21704       POR   0.401786       0.0    2024  2024-01-23  1.0       2
# 21705       DEN   0.446429       0.0    2024  2024-01-23  0.0       2
#
# [21706 rows x 143 columns]

# %%
sfs.fit(df[selected_columns], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['pf',
#  'orb%',
#  'trb%',
#  'usg%',
#  'drtg',
#  'fg_max',
#  'fga_max',
#  'fta_max',
#  'ft%_max',
#  'trb%_max',
#  'tov%_max',
#  'drtg_max',
#  'fta_opp',
#  'ft%_opp',
#  'tov_opp',
#  'drb%_opp',
#  'trb%_opp',
#  'usg%_opp',
#  'ortg_opp',
#  '3p%_max_opp',
#  'ft_max_opp',
#  'ft%_max_opp',
#  'stl_max_opp',
#  'blk_max_opp',
#  'tov_max_opp',
#  'trb%_max_opp',
#  'ast%_max_opp',
#  'stl%_max_opp',
#  'usg%_max_opp',
#  'won']

# %%
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []
    
    seasons = sorted(df["season"].unique())
    
    for i in range(start, len(seasons), step):
        season = seasons[i]
        
        train = data[data["season"] < season]
        test = data[data["season"] == season]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
predictions
# Out:
#        actual  prediction
# 5250        1           1
# 5251        0           1
# 5252        1           1
# 5253        1           0
# 5254        0           1
# ...       ...         ...
# 21701       2           0
# 21702       2           0
# 21703       2           1
# 21704       2           1
# 21705       2           0
#
# [16456 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score


predictions = predictions[predictions["actual"] != 2]
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5457201996834287

# %%
df.groupby("home").apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# home
# 0.0    0.426794
# 1.0    0.573206
# dtype: float64

# %%
df_rolling = df[list(selected_columns) + ["team", "season"]]

# %%
df_rolling
# Out:
#         mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0   0.0  0.478261  0.529412  0.377990  0.310345  0.393939  0.356295
# 1      0.0   0.0  0.347826  0.338235  0.366029  0.206897  0.212121  0.395487
# 2      0.0   0.0  0.413043  0.500000  0.322967  0.310345  0.378788  0.368171
# 3      0.0   0.0  0.391304  0.397059  0.373206  0.241379  0.227273  0.437055
# 4      0.0   0.0  0.391304  0.529412  0.277512  0.413793  0.378788  0.491686
# ...    ...   ...       ...       ...       ...       ...       ...       ...
# 21701  0.0   0.0  0.500000  0.514706  0.413876  0.517241  0.575758  0.423990
# 21702  0.0   0.0  0.521739  0.470588  0.473684  0.413793  0.484848  0.395487
# 21703  0.0   0.0  0.543478  0.411765  0.552632  0.379310  0.439394  0.395487
# 21704  0.0   0.0  0.521739  0.426471  0.511962  0.241379  0.287879  0.361045
# 21705  0.0   0.0  0.521739  0.397059  0.538278  0.172414  0.257576  0.282660
#
#              ft       fta  ...  blk%_max_opp  tov%_max_opp  usg%_max_opp  \
# 0      0.441860  0.333333  ...         0.063      0.344864      0.216667
# 1      0.418605  0.412698  ...         0.079      0.679245      0.278205
# 2      0.209302  0.253968  ...         0.140      0.509434      0.161538
# 3      0.348837  0.349206  ...         0.185      0.270440      0.089744
# 4      0.441860  0.396825  ...         0.071      0.550314      0.151282
# ...         ...       ...  ...           ...           ...           ...
# 21701  0.069767  0.063492  ...         0.136      0.198113      0.151282
# 21702  0.581395  0.492063  ...         0.052      0.213836      0.358974
# 21703  0.325581  0.253968  ...         0.039      0.163522      0.129487
# 21704  0.395349  0.428571  ...         0.037      0.290356      0.139744
# 21705  0.395349  0.317460  ...         0.078      0.315514      0.188462
#
#        ortg_max_opp  drtg_max_opp  total_opp  home_opp  won  team  season
# 0          0.530806      0.505882   0.276786       0.0  1.0   GSW    2016
# 1          0.554502      0.317647   0.419643       1.0  0.0   NOP    2016
# 2          0.345972      0.317647   0.294643       1.0  0.0   CLE    2016
# 3          0.232227      0.329412   0.276786       0.0  1.0   CHI    2016
# 4          0.800948      0.517647   0.267857       1.0  1.0   DET    2016
# ...             ...           ...        ...       ...  ...   ...     ...
# 21701      0.398104      0.505882   0.392857       0.0  0.0   BRK    2024
# 21702      0.644550      0.517647   0.794643       1.0  0.0   UTA    2024
# 21703      0.701422      0.576471   0.401786       1.0  1.0   DEN    2024
# 21704      0.251185      0.447059   0.401786       0.0  1.0   OKC    2024
# 21705      0.355450      0.494118   0.446429       0.0  0.0   IND    2024
#
# [21706 rows x 140 columns]

# %%
def find_team_averages(team):
    rolling = team[selected_columns].rolling(10).mean()
    return rolling

df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)

# %%
df_rolling
# Out:
#           mp   mp.1        fg       fga       fg%        3p       3pa  \
# 0        NaN    NaN       NaN       NaN       NaN       NaN       NaN
# 1        NaN    NaN       NaN       NaN       NaN       NaN       NaN
# 2        NaN    NaN       NaN       NaN       NaN       NaN       NaN
# 3        NaN    NaN       NaN       NaN       NaN       NaN       NaN
# 4        NaN    NaN       NaN       NaN       NaN       NaN       NaN
# ...      ...    ...       ...       ...       ...       ...       ...
# 21701  0.050  0.050  0.456522  0.451471  0.416268  0.465517  0.562121
# 21702  0.025  0.025  0.556522  0.441176  0.549522  0.444828  0.480303
# 21703  0.000  0.000  0.565217  0.364706  0.632297  0.358621  0.374242
# 21704  0.000  0.000  0.563043  0.411765  0.577990  0.410345  0.431818
# 21705  0.000  0.000  0.528261  0.444118  0.512919  0.396552  0.419697
#
#             3p%        ft       fta  ...  ast%_max_opp  stl%_max_opp  \
# 0           NaN       NaN       NaN  ...           NaN           NaN
# 1           NaN       NaN       NaN  ...           NaN           NaN
# 2           NaN       NaN       NaN  ...           NaN           NaN
# 3           NaN       NaN       NaN  ...           NaN           NaN
# 4           NaN       NaN       NaN  ...           NaN           NaN
# ...         ...       ...       ...  ...           ...           ...
# 21701  0.393943  0.323256  0.298413  ...      0.296330        0.0421
# 21702  0.425772  0.534884  0.449206  ...      0.279817        0.0745
# 21703  0.436580  0.395349  0.346032  ...      0.365138        0.0482
# 21704  0.438005  0.400000  0.347619  ...      0.316972        0.0634
# 21705  0.436105  0.360465  0.325397  ...      0.290138        0.0494
#
#        blk%_max_opp  tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  \
# 0               NaN           NaN           NaN           NaN           NaN
# 1               NaN           NaN           NaN           NaN           NaN
# 2               NaN           NaN           NaN           NaN           NaN
# 3               NaN           NaN           NaN           NaN           NaN
# 4               NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 21701        0.0982      0.442243      0.184872      0.542180      0.510588
# 21702        0.0901      0.284591      0.181410      0.422275      0.630588
# 21703        0.0769      0.267086      0.146282      0.490047      0.640000
# 21704        0.1110      0.323795      0.117436      0.418009      0.590588
# 21705        0.1208      0.572537      0.153205      0.400948      0.536471
#
#        total_opp  home_opp  won
# 0            NaN       NaN  NaN
# 1            NaN       NaN  NaN
# 2            NaN       NaN  NaN
# 3            NaN       NaN  NaN
# 4            NaN       NaN  NaN
# ...          ...       ...  ...
# 21701   0.437500       0.6  0.2
# 21702   0.516964       0.5  0.6
# 21703   0.453571       0.6  0.7
# 21704   0.432143       0.7  0.7
# 21705   0.482143       0.6  0.4
#
# [21706 rows x 138 columns]

# %%
rolling_cols = [f"{col}_10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols

df = pd.concat([df, df_rolling], axis=1)

# %%
df
# Out:
#         mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0   0.0  0.478261  0.529412  0.377990  0.310345  0.393939  0.356295
# 1      0.0   0.0  0.347826  0.338235  0.366029  0.206897  0.212121  0.395487
# 2      0.0   0.0  0.413043  0.500000  0.322967  0.310345  0.378788  0.368171
# 3      0.0   0.0  0.391304  0.397059  0.373206  0.241379  0.227273  0.437055
# 4      0.0   0.0  0.391304  0.529412  0.277512  0.413793  0.378788  0.491686
# ...    ...   ...       ...       ...       ...       ...       ...       ...
# 21701  0.0   0.0  0.500000  0.514706  0.413876  0.517241  0.575758  0.423990
# 21702  0.0   0.0  0.521739  0.470588  0.473684  0.413793  0.484848  0.395487
# 21703  0.0   0.0  0.543478  0.411765  0.552632  0.379310  0.439394  0.395487
# 21704  0.0   0.0  0.521739  0.426471  0.511962  0.241379  0.287879  0.361045
# 21705  0.0   0.0  0.521739  0.397059  0.538278  0.172414  0.257576  0.282660
#
#              ft       fta  ...  ast%_max_opp_10  stl%_max_opp_10  \
# 0      0.441860  0.333333  ...              NaN              NaN
# 1      0.418605  0.412698  ...              NaN              NaN
# 2      0.209302  0.253968  ...              NaN              NaN
# 3      0.348837  0.349206  ...              NaN              NaN
# 4      0.441860  0.396825  ...              NaN              NaN
# ...         ...       ...  ...              ...              ...
# 21701  0.069767  0.063492  ...         0.296330           0.0421
# 21702  0.581395  0.492063  ...         0.279817           0.0745
# 21703  0.325581  0.253968  ...         0.365138           0.0482
# 21704  0.395349  0.428571  ...         0.316972           0.0634
# 21705  0.395349  0.317460  ...         0.290138           0.0494
#
#        blk%_max_opp_10  tov%_max_opp_10  usg%_max_opp_10  ortg_max_opp_10  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 21701           0.0982         0.442243         0.184872         0.542180
# 21702           0.0901         0.284591         0.181410         0.422275
# 21703           0.0769         0.267086         0.146282         0.490047
# 21704           0.1110         0.323795         0.117436         0.418009
# 21705           0.1208         0.572537         0.153205         0.400948
#
#        drtg_max_opp_10  total_opp_10  home_opp_10  won_10
# 0                  NaN           NaN          NaN     NaN
# 1                  NaN           NaN          NaN     NaN
# 2                  NaN           NaN          NaN     NaN
# 3                  NaN           NaN          NaN     NaN
# 4                  NaN           NaN          NaN     NaN
# ...                ...           ...          ...     ...
# 21701         0.510588      0.437500          0.6     0.2
# 21702         0.630588      0.516964          0.5     0.6
# 21703         0.640000      0.453571          0.6     0.7
# 21704         0.590588      0.432143          0.7     0.7
# 21705         0.536471      0.482143          0.6     0.4
#
# [21706 rows x 281 columns]

# %%
df.to_csv("nba_games_rolling.csv")

# %%
df = df.dropna()

# %%
df.to_csv("nba_games_rolling_dropna.csv")

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

df["home_next"] = add_col(df, "home")
df["team_opp_next"] = add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")
# Out:
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_58359/1688004556.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["home_next"] = add_col(df, "home")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_58359/1688004556.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["home_next"] = add_col(df, "home")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_58359/1688004556.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["team_opp_next"] = add_col(df, "team_opp")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_58359/1688004556.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["team_opp_next"] = add_col(df, "team_opp")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_58359/1688004556.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["date_next"] = add_col(df, "date")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_58359/1688004556.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["date_next"] = add_col(df, "date")

# %%
df
# Out:
#         mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 224    0.0   0.0  0.500000  0.382353  0.523923  0.344828  0.333333  0.457245
# 248    0.0   0.0  0.630435  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    0.0   0.0  0.326087  0.250000  0.413876  0.310345  0.257576  0.509501
# 256    0.0   0.0  0.217391  0.279412  0.234450  0.310345  0.348485  0.395487
# 259    0.0   0.0  0.369565  0.382353  0.358852  0.206897  0.181818  0.445368
# ...    ...   ...       ...       ...       ...       ...       ...       ...
# 21701  0.0   0.0  0.500000  0.514706  0.413876  0.517241  0.575758  0.423990
# 21702  0.0   0.0  0.521739  0.470588  0.473684  0.413793  0.484848  0.395487
# 21703  0.0   0.0  0.543478  0.411765  0.552632  0.379310  0.439394  0.395487
# 21704  0.0   0.0  0.521739  0.426471  0.511962  0.241379  0.287879  0.361045
# 21705  0.0   0.0  0.521739  0.397059  0.538278  0.172414  0.257576  0.282660
#
#              ft       fta  ...  tov%_max_opp_10  usg%_max_opp_10  \
# 224    0.255814  0.238095  ...         0.413522         0.125256
# 248    0.325581  0.238095  ...         0.469497         0.220641
# 252    0.511628  0.412698  ...         0.380294         0.274359
# 256    0.372093  0.317460  ...         0.373480         0.142436
# 259    0.511628  0.412698  ...         0.437841         0.139231
# ...         ...       ...  ...              ...              ...
# 21701  0.069767  0.063492  ...         0.442243         0.184872
# 21702  0.581395  0.492063  ...         0.284591         0.181410
# 21703  0.325581  0.253968  ...         0.267086         0.146282
# 21704  0.395349  0.428571  ...         0.323795         0.117436
# 21705  0.395349  0.317460  ...         0.572537         0.153205
#
#        ortg_max_opp_10  drtg_max_opp_10  total_opp_10  home_opp_10  won_10  \
# 224           0.361611         0.449412      0.322321          0.4     0.8
# 248           0.394787         0.531765      0.300893          0.5     1.0
# 252           0.270616         0.478824      0.286607          0.6     0.7
# 256           0.320379         0.429412      0.318750          0.5     0.4
# 259           0.507109         0.360000      0.326786          0.6     0.4
# ...                ...              ...           ...          ...     ...
# 21701         0.542180         0.510588      0.437500          0.6     0.2
# 21702         0.422275         0.630588      0.516964          0.5     0.6
# 21703         0.490047         0.640000      0.453571          0.6     0.7
# 21704         0.418009         0.590588      0.432143          0.7     0.7
# 21705         0.400948         0.536471      0.482143          0.6     0.4
#
#        home_next  team_opp_next   date_next
# 224          0.0            BOS  2015-11-13
# 248          1.0            BRK  2015-11-14
# 252          0.0            SAC  2015-11-15
# 256          1.0            NOP  2015-11-15
# 259          0.0            MIN  2015-11-15
# ...          ...            ...         ...
# 21701        NaN           None        None
# 21702        NaN           None        None
# 21703        NaN           None        None
# 21704        NaN           None        None
# 21705        NaN           None        None
#
# [19276 rows x 284 columns]

# %%
df = df.copy()

# %%
full = df.merge(
    df[rolling_cols + ["team_opp_next", "date_next", "team"]], 
    left_on=["team", "date_next"], 
    right_on=["team_opp_next", "date_next"]
)

# %%
full
# Out:
#          mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.00  0.477273  0.500000  0.375598  0.379310  0.348485  0.483373
# 1      0.00  0.340909  0.250000  0.413876  0.310345  0.257576  0.509501
# 2      0.00  0.545455  0.426471  0.511962  0.275862  0.363636  0.339667
# 3      0.00  0.318182  0.323529  0.318182  0.275862  0.272727  0.432304
# 4      0.25  0.500000  0.558824  0.356459  0.068966  0.212121  0.131829
# ...     ...       ...       ...       ...       ...       ...       ...
# 15769  0.00  0.545455  0.426471  0.511962  0.448276  0.469697  0.440618
# 15770  0.00  0.477273  0.455882  0.409091  0.517241  0.590909  0.414489
# 15771  0.00  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 15772  0.00  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 15773  0.00  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
#
#              ft       fta       ft%  ...  blk%_max_opp_10_y  \
# 0      0.441860  0.396825  0.730455  ...             0.1072
# 1      0.511628  0.412698  0.827305  ...             0.1032
# 2      0.348837  0.317460  0.722287  ...             0.1826
# 3      0.186047  0.158730  0.787631  ...             0.0839
# 4      0.325581  0.238095  0.927655  ...             0.0842
# ...         ...       ...       ...  ...                ...
# 15769  0.372093  0.365079  0.659277  ...             0.1170
# 15770  0.255814  0.222222  0.766628  ...             0.1113
# 15771  0.302326  0.285714  0.693116  ...             0.1147
# 15772  0.279070  0.222222  0.844807  ...             0.1113
# 15773  0.465116  0.476190  0.623104  ...             0.1171
#
#        tov%_max_opp_10_y  usg%_max_opp_10_y  ortg_max_opp_10_y  \
# 0               0.380294           0.273427           0.270616
# 1               0.437212           0.124904           0.404739
# 2               0.427568           0.258280           0.514218
# 3               0.310377           0.127086           0.312796
# 4               0.421593           0.133504           0.345498
# ...                  ...                ...                ...
# 15769           0.457128           0.235173           0.562085
# 15770           0.471908           0.170603           0.431754
# 15771           0.431761           0.242875           0.567773
# 15772           0.483229           0.174711           0.438863
# 15773           0.374109           0.321566           0.642654
#
#        drtg_max_opp_10_y  total_opp_10_y  home_opp_10_y  won_10_y  \
# 0               0.478824        0.308654            0.6       0.7
# 1               0.408235        0.428846            0.2       0.3
# 2               0.335294        0.390385            0.5       0.0
# 3               0.410588        0.353846            0.5       0.6
# 4               0.454118        0.343269            0.4       0.7
# ...                  ...             ...            ...       ...
# 15769           0.552941        0.429808            0.4       0.6
# 15770           0.522353        0.348077            0.5       0.6
# 15771           0.575294        0.394231            0.4       0.7
# 15772           0.483529        0.350000            0.5       0.5
# 15773           0.564706        0.392308            0.4       0.7
#
#        team_opp_next_y  team_y
# 0                  SAC     TOR
# 1                  TOR     SAC
# 2                  DAL     PHI
# 3                  PHI     DAL
# 4                  BRK     ATL
# ...                ...     ...
# 15769              BOS     GSW
# 15770              GSW     BOS
# 15771              BOS     GSW
# 15772              GSW     BOS
# 15773              BOS     GSW
#
# [15774 rows x 421 columns]

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next", "season", "won"]]
# Out:
#       team_x team_opp_next_x team_y team_opp_next_y   date_next  season  won
# 0        SAC             TOR    TOR             SAC  2015-11-15    2016  1.0
# 1        TOR             SAC    SAC             TOR  2015-11-15    2016  1.0
# 2        DAL             PHI    PHI             DAL  2015-11-16    2016  1.0
# 3        PHI             DAL    DAL             PHI  2015-11-16    2016  0.0
# 4        BRK             ATL    ATL             BRK  2015-11-17    2016  0.0
# ...      ...             ...    ...             ...         ...     ...  ...
# 15769    BOS             GSW    GSW             BOS  2022-06-10    2022  1.0
# 15770    GSW             BOS    BOS             GSW  2022-06-13    2022  1.0
# 15771    BOS             GSW    GSW             BOS  2022-06-13    2022  0.0
# 15772    GSW             BOS    BOS             GSW  2022-06-16    2022  1.0
# 15773    BOS             GSW    GSW             BOS  2022-06-16    2022  0.0
#
# [15774 rows x 7 columns]

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns + ["won"]

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]

# %%
sfs.fit(full[selected_columns], full["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['fta',
#  'usg%',
#  'ft%_max',
#  'drb_max',
#  'efg%_max',
#  'trb%_max',
#  'pf_opp',
#  'usg%_opp',
#  'blk_max_opp',
#  'ftr_max_opp',
#  'ast%_max_opp',
#  'ast_10_x',
#  'usg%_10_x',
#  'ft%_max_10_x',
#  'ts%_max_10_x',
#  'ftr_opp_10_x',
#  'usg%_opp_10_x',
#  'drb_max_opp_10_x',
#  'ftr_max_opp_10_x',
#  'won_10_x',
#  'home_next',
#  'orb%_10_y',
#  'usg%_10_y',
#  '+/-_max_10_y',
#  'efg%_max_10_y',
#  'pf_opp_10_y',
#  'efg%_opp_10_y',
#  'usg%_opp_10_y',
#  '+/-_max_opp_10_y',
#  'won_10_y']

# %%
predictions = backtest(full, rr, predictors)

# %%
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.6322429485446517

# %%
predictions
# Out:
#        actual  prediction
# 4677        1           1
# 4678        1           0
# 4679        1           1
# 4680        1           1
# 4681        1           1
# ...       ...         ...
# 15769       0           1
# 15770       1           1
# 15771       0           0
# 15772       1           1
# 15773       0           0
#
# [11097 rows x 2 columns]

# %%
full[selected_columns]
# Out:
#          mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.00  0.477273  0.500000  0.375598  0.379310  0.348485  0.483373
# 1      0.00  0.340909  0.250000  0.413876  0.310345  0.257576  0.509501
# 2      0.00  0.545455  0.426471  0.511962  0.275862  0.363636  0.339667
# 3      0.00  0.318182  0.323529  0.318182  0.275862  0.272727  0.432304
# 4      0.25  0.500000  0.558824  0.356459  0.068966  0.212121  0.131829
# ...     ...       ...       ...       ...       ...       ...       ...
# 15769  0.00  0.545455  0.426471  0.511962  0.448276  0.469697  0.440618
# 15770  0.00  0.477273  0.455882  0.409091  0.517241  0.590909  0.414489
# 15771  0.00  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 15772  0.00  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 15773  0.00  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
#
#              ft       fta       ft%  ...  ast%_max_opp_10_y  \
# 0      0.441860  0.396825  0.730455  ...           0.458257
# 1      0.511628  0.412698  0.827305  ...           0.331537
# 2      0.348837  0.317460  0.722287  ...           0.533142
# 3      0.186047  0.158730  0.787631  ...           0.341743
# 4      0.325581  0.238095  0.927655  ...           0.321560
# ...         ...       ...       ...  ...                ...
# 15769  0.372093  0.365079  0.659277  ...           0.504472
# 15770  0.255814  0.222222  0.766628  ...           0.373394
# 15771  0.302326  0.285714  0.693116  ...           0.470528
# 15772  0.279070  0.222222  0.844807  ...           0.384060
# 15773  0.465116  0.476190  0.623104  ...           0.546101
#
#        stl%_max_opp_10_y  blk%_max_opp_10_y  tov%_max_opp_10_y  \
# 0                 0.0699             0.1072           0.380294
# 1                 0.0657             0.1032           0.437212
# 2                 0.0549             0.1826           0.427568
# 3                 0.0574             0.0839           0.310377
# 4                 0.0632             0.0842           0.421593
# ...                  ...                ...                ...
# 15769             0.0745             0.1170           0.457128
# 15770             0.0570             0.1113           0.471908
# 15771             0.0737             0.1147           0.431761
# 15772             0.0591             0.1113           0.483229
# 15773             0.0716             0.1171           0.374109
#
#        usg%_max_opp_10_y  ortg_max_opp_10_y  drtg_max_opp_10_y  \
# 0               0.273427           0.270616           0.478824
# 1               0.124904           0.404739           0.408235
# 2               0.258280           0.514218           0.335294
# 3               0.127086           0.312796           0.410588
# 4               0.133504           0.345498           0.454118
# ...                  ...                ...                ...
# 15769           0.235173           0.562085           0.552941
# 15770           0.170603           0.431754           0.522353
# 15771           0.242875           0.567773           0.575294
# 15772           0.174711           0.438863           0.483529
# 15773           0.321566           0.642654           0.564706
#
#        total_opp_10_y  home_opp_10_y  won_10_y
# 0            0.308654            0.6       0.7
# 1            0.428846            0.2       0.3
# 2            0.390385            0.5       0.0
# 3            0.353846            0.5       0.6
# 4            0.343269            0.4       0.7
# ...               ...            ...       ...
# 15769        0.429808            0.4       0.6
# 15770        0.348077            0.5       0.6
# 15771        0.394231            0.4       0.7
# 15772        0.350000            0.5       0.5
# 15773        0.392308            0.4       0.7
#
# [15774 rows x 411 columns]
