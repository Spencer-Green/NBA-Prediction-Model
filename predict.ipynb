# %%
import pandas as pd

# %%
df = pd.read_csv("nba_updated_games.csv", index_col=0)
#df_updated = pd.read_csv("nba_updated_fixtures.csv", index_col=0)

# %%
df
# Out:
#        Unnamed: 0     mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft  \
# 0               0  240.0  240.0  38.0  72.0  0.528  16.0  37.0  0.432  18.0
# 1               1  240.0  240.0  40.0  84.0  0.476  14.0  39.0  0.359  13.0
# 2               2  240.0  240.0  41.0  78.0  0.526   8.0  24.0  0.333  15.0
# 3               3  240.0  240.0  29.0  74.0  0.392  13.0  38.0  0.342  19.0
# 4               4  240.0  240.0  39.0  81.0  0.481   6.0  20.0  0.300  14.0
# ...           ...    ...    ...   ...   ...    ...   ...   ...    ...   ...
# 21987         281  240.0  240.0  42.0  90.0  0.467  15.0  41.0  0.366   8.0
# 21988         282  240.0  240.0  48.0  95.0  0.505   9.0  32.0  0.281  22.0
# 21989         283  240.0  240.0  44.0  96.0  0.458   6.0  32.0  0.188  13.0
# 21990         284  240.0  240.0  45.0  81.0  0.556  16.0  31.0  0.516  15.0
# 21991         285  240.0  240.0  47.0  89.0  0.528  12.0  35.0  0.343  22.0
#
#        ...  tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0      ...          26.2          26.8         155.0         123.0       MIA
# 1      ...          41.0          37.3         160.0         121.0       POR
# 2      ...          28.6          41.1         250.0         125.0       DAL
# 3      ...          12.6          33.0         183.0         110.0       CLE
# 4      ...          22.8          29.0         178.0         111.0       DAL
# ...    ...           ...           ...           ...           ...       ...
# 21987  ...          23.5          37.3         179.0         122.0       ORL
# 21988  ...          50.0          53.1         214.0         134.0       TOR
# 21989  ...          33.3          29.5         209.0         116.0       LAC
# 21990  ...          25.0          40.5         181.0         134.0       CLE
# 21991  ...          40.0          26.5         196.0         142.0       DET
#
#        total_opp  home_opp  season        date    won
# 0            107         1    2023  2022-11-07   True
# 1            110         0    2023  2022-11-07  False
# 2             90         1    2023  2022-12-14   True
# 3            105         0    2023  2022-12-14  False
# 4             95         1    2016  2015-12-09   True
# ...          ...       ...     ...         ...    ...
# 21987        106         0    2024  2024-01-26   True
# 21988        107         1    2024  2024-01-26   True
# 21989        127         0    2024  2024-01-26  False
# 21990        128         1    2024  2024-01-31  False
# 21991        121         0    2024  2024-01-31   True
#
# [21992 rows x 151 columns]

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)

# %%
def add_target(team):
    team["target"] = team["won"].shift(-1)
    return team

df = df.groupby("team", group_keys=False).apply(add_target)

# %%
df[df["team"] == "WAS"]
# Out:
#        Unnamed: 0     mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft  \
# 30          16508  240.0  240.0  33.0  84.0  0.393   7.0  28.0  0.250  15.0
# 60           1776  240.0  240.0  35.0  68.0  0.515  12.0  21.0  0.571  36.0
# 72          13907  240.0  240.0  38.0  90.0  0.422   6.0  22.0  0.273  28.0
# 128          2633  240.0  240.0  42.0  87.0  0.483   8.0  23.0  0.348  10.0
# 163         18880  240.0  240.0  36.0  88.0  0.409   8.0  25.0  0.320  18.0
# ...           ...    ...    ...   ...   ...    ...   ...   ...    ...   ...
# 21869          45  240.0  240.0  37.0  90.0  0.411  11.0  42.0  0.262  17.0
# 21898          91  240.0  240.0  47.0  96.0  0.490   7.0  32.0  0.219  11.0
# 21929         255  240.0  240.0  42.0  94.0  0.447  16.0  40.0  0.400   6.0
# 21961          94  240.0  240.0  45.0  95.0  0.474  20.0  47.0  0.426  19.0
# 21971         203  240.0  240.0  42.0  86.0  0.488  13.0  35.0  0.371  16.0
#
#        ...  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 30     ...          25.2         134.0          98.0       ORL         87
# 60     ...          32.4         138.0         122.0       MIL        113
# 72     ...          28.7         153.0         108.0       NYK        117
# 128    ...          30.0         160.0         109.0       SAS         99
# 163    ...          41.6         146.0         103.0       BOS        118
# ...    ...           ...           ...           ...       ...        ...
# 21869  ...          27.5         163.0         107.0       MIA        110
# 21898  ...          34.7         168.0         115.0       PHO        140
# 21929  ...          37.8         161.0         114.0       CLE        114
# 21961  ...          33.8         151.0         123.0       BOS        133
# 21971  ...          31.8         161.0         117.0       PHI        119
#
#        home_opp  season        date    won  target
# 30            1    2016  2015-10-28   True    True
# 60            1    2016  2015-10-30   True   False
# 72            0    2016  2015-10-31  False    True
# 128           0    2016  2015-11-04   True   False
# 163           1    2016  2015-11-06  False   False
# ...         ...     ...         ...    ...     ...
# 21869         0    2024  2024-02-02  False   False
# 21898         0    2024  2024-02-04  False   False
# 21929         0    2024  2024-02-07  False   False
# 21961         1    2024  2024-02-09  False   False
# 21971         0    2024  2024-02-10  False     NaN
#
# [714 rows x 152 columns]

# %%
df["target"][pd.isnull(df["target"])] = 2
# Out:
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_52337/1618397414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["target"][pd.isnull(df["target"])] = 2

# %%
df["target"] = df["target"].astype(int, errors="ignore")

# %%
df
# Out:
#        Unnamed: 0     mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft  \
# 0           19623  240.0  240.0  41.0   96.0  0.427   9.0  30.0  0.300  20.0
# 1           19622  240.0  240.0  35.0   83.0  0.422   6.0  18.0  0.333  19.0
# 2           20640  240.0  240.0  38.0   94.0  0.404   9.0  29.0  0.310  10.0
# 3           20641  240.0  240.0  37.0   87.0  0.425   7.0  19.0  0.368  16.0
# 4            1512  240.0  240.0  37.0   96.0  0.385  12.0  29.0  0.414  20.0
# ...           ...    ...    ...   ...    ...    ...   ...   ...    ...   ...
# 21987         252  240.0  240.0  43.0   92.0  0.467  16.0  44.0  0.364   4.0
# 21988          63  240.0  240.0  40.0   84.0  0.476  10.0  32.0  0.313  21.0
# 21989          62  240.0  240.0  50.0   82.0  0.610  14.0  29.0  0.483  11.0
# 21990         179  240.0  240.0  45.0  101.0  0.446  17.0  41.0  0.415   6.0
# 21991         238  240.0  240.0  36.0   76.0  0.474  10.0  27.0  0.370  11.0
#
#        ...  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0      ...          38.9         201.0         120.0       NOP         95
# 1      ...          43.7         206.0         104.0       GSW        111
# 2      ...          34.6         162.0         104.0       CHI         97
# 3      ...          29.0         138.0         105.0       CLE         95
# 4      ...          33.8         258.0         121.0       ATL         94
# ...    ...           ...           ...           ...       ...        ...
# 21987  ...          28.1         169.0         117.0       CHO        115
# 21988  ...          28.1         175.0         120.0       IND        125
# 21989  ...          39.7         169.0         133.0       NYK        111
# 21990  ...          33.8         254.0         118.0       PHO        112
# 21991  ...          31.7         169.0         117.0       POR         84
#
#        home_opp  season        date    won  target
# 0             0    2016  2015-10-27   True       1
# 1             1    2016  2015-10-27  False       0
# 2             1    2016  2015-10-27  False       1
# 3             0    2016  2015-10-27   True       1
# 4             1    2016  2015-10-27   True       1
# ...         ...     ...         ...    ...     ...
# 21987         1    2024  2024-02-10  False       2
# 21988         0    2024  2024-02-10  False       2
# 21989         1    2024  2024-02-10   True       2
# 21990         0    2024  2024-02-10   True       2
# 21991         1    2024  2024-02-10   True       2
#
# [21992 rows x 152 columns]

# %%
df["won"].value_counts()
# Out:
# won
# True     10996
# False    10996
# Name: count, dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 1    10982
# 0    10980
# 2       30
# Name: count, dtype: int64

# %%
nulls = pd.isnull(df)

# %%
nulls = nulls.sum()

# %%
nulls = nulls[nulls > 0]

# %%
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['Unnamed: 0', 'mp', 'mp.1', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%',
#        'ft',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=144)

# %%
df = df[valid_columns].copy()

# %%
df
# Out:
#        Unnamed: 0     mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft  \
# 0           19623  240.0  240.0  41.0   96.0  0.427   9.0  30.0  0.300  20.0
# 1           19622  240.0  240.0  35.0   83.0  0.422   6.0  18.0  0.333  19.0
# 2           20640  240.0  240.0  38.0   94.0  0.404   9.0  29.0  0.310  10.0
# 3           20641  240.0  240.0  37.0   87.0  0.425   7.0  19.0  0.368  16.0
# 4            1512  240.0  240.0  37.0   96.0  0.385  12.0  29.0  0.414  20.0
# ...           ...    ...    ...   ...    ...    ...   ...   ...    ...   ...
# 21987         252  240.0  240.0  43.0   92.0  0.467  16.0  44.0  0.364   4.0
# 21988          63  240.0  240.0  40.0   84.0  0.476  10.0  32.0  0.313  21.0
# 21989          62  240.0  240.0  50.0   82.0  0.610  14.0  29.0  0.483  11.0
# 21990         179  240.0  240.0  45.0  101.0  0.446  17.0  41.0  0.415   6.0
# 21991         238  240.0  240.0  36.0   76.0  0.474  10.0  27.0  0.370  11.0
#
#        ...  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0      ...          38.9         201.0         120.0       NOP         95
# 1      ...          43.7         206.0         104.0       GSW        111
# 2      ...          34.6         162.0         104.0       CHI         97
# 3      ...          29.0         138.0         105.0       CLE         95
# 4      ...          33.8         258.0         121.0       ATL         94
# ...    ...           ...           ...           ...       ...        ...
# 21987  ...          28.1         169.0         117.0       CHO        115
# 21988  ...          28.1         175.0         120.0       IND        125
# 21989  ...          39.7         169.0         133.0       NYK        111
# 21990  ...          33.8         254.0         118.0       PHO        112
# 21991  ...          31.7         169.0         117.0       POR         84
#
#        home_opp  season        date    won  target
# 0             0    2016  2015-10-27   True       1
# 1             1    2016  2015-10-27  False       0
# 2             1    2016  2015-10-27  False       1
# 3             0    2016  2015-10-27   True       1
# 4             1    2016  2015-10-27   True       1
# ...         ...     ...         ...    ...     ...
# 21987         1    2024  2024-02-10  False       2
# 21988         0    2024  2024-02-10  False       2
# 21989         1    2024  2024-02-10   True       2
# 21990         0    2024  2024-02-10   True       2
# 21991         1    2024  2024-02-10   True       2
#
# [21992 rows x 144 columns]

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha=1)
split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr, n_features_to_select=30, direction="forward", cv=split)

# %%
removed_columns = ["season", "won", "date", "target", "team", "team_opp"]

# %%
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
df
# Out:
#         mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0   0.0  0.478261  0.529412  0.377990  0.310345  0.393939  0.356295
# 1      0.0   0.0  0.347826  0.338235  0.366029  0.206897  0.212121  0.395487
# 2      0.0   0.0  0.413043  0.500000  0.322967  0.310345  0.378788  0.368171
# 3      0.0   0.0  0.391304  0.397059  0.373206  0.241379  0.227273  0.437055
# 4      0.0   0.0  0.391304  0.529412  0.277512  0.413793  0.378788  0.491686
# ...    ...   ...       ...       ...       ...       ...       ...       ...
# 21987  0.0   0.0  0.521739  0.470588  0.473684  0.551724  0.606061  0.432304
# 21988  0.0   0.0  0.456522  0.352941  0.495215  0.344828  0.424242  0.371734
# 21989  0.0   0.0  0.673913  0.323529  0.815789  0.482759  0.378788  0.573634
# 21990  0.0   0.0  0.565217  0.602941  0.423445  0.586207  0.560606  0.492874
# 21991  0.0   0.0  0.369565  0.235294  0.490431  0.344828  0.348485  0.439430
#
#              ft       fta  ...  usg%_max_opp  ortg_max_opp  drtg_max_opp  \
# 0      0.441860  0.333333  ...      0.216667      0.530806      0.505882
# 1      0.418605  0.412698  ...      0.278205      0.554502      0.317647
# 2      0.209302  0.253968  ...      0.161538      0.345972      0.317647
# 3      0.348837  0.349206  ...      0.089744      0.232227      0.329412
# 4      0.441860  0.396825  ...      0.151282      0.800948      0.517647
# ...         ...       ...  ...           ...           ...           ...
# 21987  0.069767  0.111111  ...      0.078205      0.379147      0.470588
# 21988  0.465116  0.349206  ...      0.078205      0.407583      0.505882
# 21989  0.232558  0.285714  ...      0.226923      0.379147      0.658824
# 21990  0.116279  0.158730  ...      0.151282      0.781991      0.482353
# 21991  0.232558  0.238095  ...      0.124359      0.379147      0.470588
#
#        team_opp  total_opp  home_opp  season        date    won  target
# 0           NOP   0.276786       0.0    2016  2015-10-27   True       1
# 1           GSW   0.419643       1.0    2016  2015-10-27  False       0
# 2           CHI   0.294643       1.0    2016  2015-10-27  False       1
# 3           CLE   0.276786       0.0    2016  2015-10-27   True       1
# 4           ATL   0.267857       1.0    2016  2015-10-27   True       1
# ...         ...        ...       ...     ...         ...    ...     ...
# 21987       CHO   0.455357       1.0    2024  2024-02-10  False       2
# 21988       IND   0.544643       0.0    2024  2024-02-10  False       2
# 21989       NYK   0.419643       1.0    2024  2024-02-10   True       2
# 21990       PHO   0.428571       0.0    2024  2024-02-10   True       2
# 21991       POR   0.178571       1.0    2024  2024-02-10   True       2
#
# [21992 rows x 143 columns]

# %%
sfs.fit(df[selected_columns], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['ft',
#  'orb',
#  'ftr',
#  'trb%',
#  'usg%',
#  'ft_max',
#  'fta_max',
#  'ft%_max',
#  'trb_max',
#  'tov_max',
#  'trb%_max',
#  'usg%_max',
#  'fg%_opp',
#  '3p_opp',
#  'ft_opp',
#  'fta_opp',
#  'orb_opp',
#  'blk_opp',
#  'pf_opp',
#  'ts%_opp',
#  'efg%_opp',
#  'ftr_opp',
#  'trb%_opp',
#  'blk%_opp',
#  'usg%_opp',
#  'ft%_max_opp',
#  'stl_max_opp',
#  'ast%_max_opp',
#  'stl%_max_opp',
#  'usg%_max_opp']

# %%
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []
    
    seasons = sorted(df["season"].unique())
    
    for i in range(start, len(seasons), step):
        season = seasons[i]
        
        train = data[data["season"] < season]
        test = data[data["season"] == season]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
predictions
# Out:
#        actual  prediction
# 5250        1           1
# 5251        1           0
# 5252        1           0
# 5253        0           1
# 5254        0           0
# ...       ...         ...
# 21987       2           0
# 21988       2           0
# 21989       2           0
# 21990       2           1
# 21991       2           1
#
# [16742 rows x 2 columns]

# %%
df = df[5250:21992]

# %%
predictions_df = pd.concat([predictions, df], ignore_index=False, axis=1)

# %%
predictions_df.to_csv('predictions_df.csv')

# %%
from sklearn.metrics import accuracy_score


predictions = predictions[predictions["actual"] != 2]
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5426041168022977

# %%
df.groupby("home").apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# home
# 0.0    0.426794
# 1.0    0.573206
# dtype: float64

# %%
df_rolling = df[list(selected_columns) + ["team", "season"]]

# %%
df_rolling
# Out:
#         mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0   0.0  0.478261  0.529412  0.377990  0.310345  0.393939  0.356295
# 1      0.0   0.0  0.347826  0.338235  0.366029  0.206897  0.212121  0.395487
# 2      0.0   0.0  0.413043  0.500000  0.322967  0.310345  0.378788  0.368171
# 3      0.0   0.0  0.391304  0.397059  0.373206  0.241379  0.227273  0.437055
# 4      0.0   0.0  0.391304  0.529412  0.277512  0.413793  0.378788  0.491686
# ...    ...   ...       ...       ...       ...       ...       ...       ...
# 21701  0.0   0.0  0.500000  0.514706  0.413876  0.517241  0.575758  0.423990
# 21702  0.0   0.0  0.521739  0.470588  0.473684  0.413793  0.484848  0.395487
# 21703  0.0   0.0  0.543478  0.411765  0.552632  0.379310  0.439394  0.395487
# 21704  0.0   0.0  0.521739  0.426471  0.511962  0.241379  0.287879  0.361045
# 21705  0.0   0.0  0.521739  0.397059  0.538278  0.172414  0.257576  0.282660
#
#              ft       fta  ...  stl%_max_opp  blk%_max_opp  tov%_max_opp  \
# 0      0.441860  0.333333  ...         0.053         0.063      0.344864
# 1      0.418605  0.412698  ...         0.191         0.079      0.679245
# 2      0.209302  0.253968  ...         0.028         0.140      0.509434
# 3      0.348837  0.349206  ...         0.028         0.185      0.270440
# 4      0.441860  0.396825  ...         0.106         0.071      0.550314
# ...         ...       ...  ...           ...           ...           ...
# 21701  0.069767  0.063492  ...         0.062         0.136      0.198113
# 21702  0.581395  0.492063  ...         0.027         0.052      0.213836
# 21703  0.325581  0.253968  ...         0.046         0.039      0.163522
# 21704  0.395349  0.428571  ...         0.066         0.037      0.290356
# 21705  0.395349  0.317460  ...         0.042         0.078      0.315514
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  total_opp  home_opp  team  \
# 0          0.216667      0.530806      0.505882   0.276786       0.0   GSW
# 1          0.278205      0.554502      0.317647   0.419643       1.0   NOP
# 2          0.161538      0.345972      0.317647   0.294643       1.0   CLE
# 3          0.089744      0.232227      0.329412   0.276786       0.0   CHI
# 4          0.151282      0.800948      0.517647   0.267857       1.0   DET
# ...             ...           ...           ...        ...       ...   ...
# 21701      0.151282      0.398104      0.505882   0.392857       0.0   BRK
# 21702      0.358974      0.644550      0.517647   0.794643       1.0   UTA
# 21703      0.129487      0.701422      0.576471   0.401786       1.0   DEN
# 21704      0.139744      0.251185      0.447059   0.401786       0.0   OKC
# 21705      0.188462      0.355450      0.494118   0.446429       0.0   IND
#
#        season
# 0        2016
# 1        2016
# 2        2016
# 3        2016
# 4        2016
# ...       ...
# 21701    2024
# 21702    2024
# 21703    2024
# 21704    2024
# 21705    2024
#
# [21706 rows x 139 columns]

# %%
def find_team_averages(team):
    rolling = team[selected_columns].rolling(10).mean()
    return rolling

df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)

# %%
df_rolling
# Out:
#           mp   mp.1        fg       fga       fg%        3p       3pa  \
# 0        NaN    NaN       NaN       NaN       NaN       NaN       NaN
# 1        NaN    NaN       NaN       NaN       NaN       NaN       NaN
# 2        NaN    NaN       NaN       NaN       NaN       NaN       NaN
# 3        NaN    NaN       NaN       NaN       NaN       NaN       NaN
# 4        NaN    NaN       NaN       NaN       NaN       NaN       NaN
# ...      ...    ...       ...       ...       ...       ...       ...
# 21701  0.050  0.050  0.456522  0.451471  0.416268  0.465517  0.562121
# 21702  0.025  0.025  0.556522  0.441176  0.549522  0.444828  0.480303
# 21703  0.000  0.000  0.565217  0.364706  0.632297  0.358621  0.374242
# 21704  0.000  0.000  0.563043  0.411765  0.577990  0.410345  0.431818
# 21705  0.000  0.000  0.528261  0.444118  0.512919  0.396552  0.419697
#
#             3p%        ft       fta  ...  trb%_max_opp  ast%_max_opp  \
# 0           NaN       NaN       NaN  ...           NaN           NaN
# 1           NaN       NaN       NaN  ...           NaN           NaN
# 2           NaN       NaN       NaN  ...           NaN           NaN
# 3           NaN       NaN       NaN  ...           NaN           NaN
# 4           NaN       NaN       NaN  ...           NaN           NaN
# ...         ...       ...       ...  ...           ...           ...
# 21701  0.393943  0.323256  0.298413  ...      0.190570      0.296330
# 21702  0.425772  0.534884  0.449206  ...      0.182456      0.279817
# 21703  0.436580  0.395349  0.346032  ...      0.148904      0.365138
# 21704  0.438005  0.400000  0.347619  ...      0.164364      0.316972
# 21705  0.436105  0.360465  0.325397  ...      0.175658      0.290138
#
#        stl%_max_opp  blk%_max_opp  tov%_max_opp  usg%_max_opp  ortg_max_opp  \
# 0               NaN           NaN           NaN           NaN           NaN
# 1               NaN           NaN           NaN           NaN           NaN
# 2               NaN           NaN           NaN           NaN           NaN
# 3               NaN           NaN           NaN           NaN           NaN
# 4               NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 21701        0.0421        0.0982      0.442243      0.184872      0.542180
# 21702        0.0745        0.0901      0.284591      0.181410      0.422275
# 21703        0.0482        0.0769      0.267086      0.146282      0.490047
# 21704        0.0634        0.1110      0.323795      0.117436      0.418009
# 21705        0.0494        0.1208      0.572537      0.153205      0.400948
#
#        drtg_max_opp  total_opp  home_opp
# 0               NaN        NaN       NaN
# 1               NaN        NaN       NaN
# 2               NaN        NaN       NaN
# 3               NaN        NaN       NaN
# 4               NaN        NaN       NaN
# ...             ...        ...       ...
# 21701      0.510588   0.437500       0.6
# 21702      0.630588   0.516964       0.5
# 21703      0.640000   0.453571       0.6
# 21704      0.590588   0.432143       0.7
# 21705      0.536471   0.482143       0.6
#
# [21706 rows x 137 columns]

# %%
rolling_cols = [f"{col}_10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols

df = pd.concat([df, df_rolling], axis=1)

# %%
df
# Out:
#         mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0   0.0  0.478261  0.529412  0.377990  0.310345  0.393939  0.356295
# 1      0.0   0.0  0.347826  0.338235  0.366029  0.206897  0.212121  0.395487
# 2      0.0   0.0  0.413043  0.500000  0.322967  0.310345  0.378788  0.368171
# 3      0.0   0.0  0.391304  0.397059  0.373206  0.241379  0.227273  0.437055
# 4      0.0   0.0  0.391304  0.529412  0.277512  0.413793  0.378788  0.491686
# ...    ...   ...       ...       ...       ...       ...       ...       ...
# 21701  0.0   0.0  0.500000  0.514706  0.413876  0.517241  0.575758  0.423990
# 21702  0.0   0.0  0.521739  0.470588  0.473684  0.413793  0.484848  0.395487
# 21703  0.0   0.0  0.543478  0.411765  0.552632  0.379310  0.439394  0.395487
# 21704  0.0   0.0  0.521739  0.426471  0.511962  0.241379  0.287879  0.361045
# 21705  0.0   0.0  0.521739  0.397059  0.538278  0.172414  0.257576  0.282660
#
#              ft       fta  ...  trb%_max_opp_10  ast%_max_opp_10  \
# 0      0.441860  0.333333  ...              NaN              NaN
# 1      0.418605  0.412698  ...              NaN              NaN
# 2      0.209302  0.253968  ...              NaN              NaN
# 3      0.348837  0.349206  ...              NaN              NaN
# 4      0.441860  0.396825  ...              NaN              NaN
# ...         ...       ...  ...              ...              ...
# 21701  0.069767  0.063492  ...         0.190570         0.296330
# 21702  0.581395  0.492063  ...         0.182456         0.279817
# 21703  0.325581  0.253968  ...         0.148904         0.365138
# 21704  0.395349  0.428571  ...         0.164364         0.316972
# 21705  0.395349  0.317460  ...         0.175658         0.290138
#
#        stl%_max_opp_10  blk%_max_opp_10  tov%_max_opp_10  usg%_max_opp_10  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 21701           0.0421           0.0982         0.442243         0.184872
# 21702           0.0745           0.0901         0.284591         0.181410
# 21703           0.0482           0.0769         0.267086         0.146282
# 21704           0.0634           0.1110         0.323795         0.117436
# 21705           0.0494           0.1208         0.572537         0.153205
#
#        ortg_max_opp_10  drtg_max_opp_10  total_opp_10  home_opp_10
# 0                  NaN              NaN           NaN          NaN
# 1                  NaN              NaN           NaN          NaN
# 2                  NaN              NaN           NaN          NaN
# 3                  NaN              NaN           NaN          NaN
# 4                  NaN              NaN           NaN          NaN
# ...                ...              ...           ...          ...
# 21701         0.542180         0.510588      0.437500          0.6
# 21702         0.422275         0.630588      0.516964          0.5
# 21703         0.490047         0.640000      0.453571          0.6
# 21704         0.418009         0.590588      0.432143          0.7
# 21705         0.400948         0.536471      0.482143          0.6
#
# [21706 rows x 280 columns]

# %%
df = df.dropna()

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

df["home_next"] = add_col(df, "home")
df["team_opp_next"] = add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")
# Out:
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_30390/1688004556.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["home_next"] = add_col(df, "home")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_30390/1688004556.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["home_next"] = add_col(df, "home")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_30390/1688004556.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["team_opp_next"] = add_col(df, "team_opp")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_30390/1688004556.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["team_opp_next"] = add_col(df, "team_opp")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_30390/1688004556.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["date_next"] = add_col(df, "date")
# /var/folders/mv/f4c9n99j583b7mz1mbs2815h0000gn/T/ipykernel_30390/1688004556.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["date_next"] = add_col(df, "date")

# %%
df
# Out:
#         mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 224    0.0   0.0  0.500000  0.382353  0.523923  0.344828  0.333333  0.457245
# 248    0.0   0.0  0.630435  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    0.0   0.0  0.326087  0.250000  0.413876  0.310345  0.257576  0.509501
# 256    0.0   0.0  0.217391  0.279412  0.234450  0.310345  0.348485  0.395487
# 259    0.0   0.0  0.369565  0.382353  0.358852  0.206897  0.181818  0.445368
# ...    ...   ...       ...       ...       ...       ...       ...       ...
# 21701  0.0   0.0  0.500000  0.514706  0.413876  0.517241  0.575758  0.423990
# 21702  0.0   0.0  0.521739  0.470588  0.473684  0.413793  0.484848  0.395487
# 21703  0.0   0.0  0.543478  0.411765  0.552632  0.379310  0.439394  0.395487
# 21704  0.0   0.0  0.521739  0.426471  0.511962  0.241379  0.287879  0.361045
# 21705  0.0   0.0  0.521739  0.397059  0.538278  0.172414  0.257576  0.282660
#
#              ft       fta  ...  blk%_max_opp_10  tov%_max_opp_10  \
# 224    0.255814  0.238095  ...           0.0679         0.413522
# 248    0.325581  0.238095  ...           0.0772         0.469497
# 252    0.511628  0.412698  ...           0.1072         0.380294
# 256    0.372093  0.317460  ...           0.0626         0.373480
# 259    0.511628  0.412698  ...           0.1145         0.437841
# ...         ...       ...  ...              ...              ...
# 21701  0.069767  0.063492  ...           0.0982         0.442243
# 21702  0.581395  0.492063  ...           0.0901         0.284591
# 21703  0.325581  0.253968  ...           0.0769         0.267086
# 21704  0.395349  0.428571  ...           0.1110         0.323795
# 21705  0.395349  0.317460  ...           0.1208         0.572537
#
#        usg%_max_opp_10  ortg_max_opp_10  drtg_max_opp_10  total_opp_10  \
# 224           0.125256         0.361611         0.449412      0.322321
# 248           0.220641         0.394787         0.531765      0.300893
# 252           0.274359         0.270616         0.478824      0.286607
# 256           0.142436         0.320379         0.429412      0.318750
# 259           0.139231         0.507109         0.360000      0.326786
# ...                ...              ...              ...           ...
# 21701         0.184872         0.542180         0.510588      0.437500
# 21702         0.181410         0.422275         0.630588      0.516964
# 21703         0.146282         0.490047         0.640000      0.453571
# 21704         0.117436         0.418009         0.590588      0.432143
# 21705         0.153205         0.400948         0.536471      0.482143
#
#        home_opp_10  home_next  team_opp_next   date_next
# 224            0.4        0.0            BOS  2015-11-13
# 248            0.5        1.0            BRK  2015-11-14
# 252            0.6        0.0            SAC  2015-11-15
# 256            0.5        1.0            NOP  2015-11-15
# 259            0.6        0.0            MIN  2015-11-15
# ...            ...        ...            ...         ...
# 21701          0.6        NaN           None        None
# 21702          0.5        NaN           None        None
# 21703          0.6        NaN           None        None
# 21704          0.7        NaN           None        None
# 21705          0.6        NaN           None        None
#
# [19276 rows x 283 columns]

# %%
df = df.copy()

# %%
full = df.merge(
    df[rolling_cols + ["team_opp_next", "date_next", "team"]], 
    left_on=["team", "date_next"], 
    right_on=["team_opp_next", "date_next"]
)

# %%
full
# Out:
#         mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0   0.0  0.326087  0.250000  0.413876  0.310345  0.257576  0.509501
# 1      0.0   0.0  0.456522  0.500000  0.375598  0.379310  0.348485  0.483373
# 2      0.0   0.0  0.413043  0.397059  0.401914  0.137931  0.212121  0.263658
# 3      0.5   0.5  0.391304  0.455882  0.330144  0.482759  0.515152  0.437055
# 4      0.0   0.0  0.304348  0.323529  0.318182  0.275862  0.272727  0.432304
# ...    ...   ...       ...       ...       ...       ...       ...       ...
# 19143  0.0   0.0  0.500000  0.441176  0.473684  0.310345  0.378788  0.368171
# 19144  0.0   0.0  0.543478  0.441176  0.526316  0.482759  0.530303  0.426366
# 19145  0.0   0.0  0.521739  0.558824  0.406699  0.586207  0.651515  0.429929
# 19146  0.0   0.0  0.608696  0.323529  0.727273  0.275862  0.318182  0.380048
# 19147  0.0   0.0  0.500000  0.338235  0.566986  0.448276  0.333333  0.593824
#
#              ft       fta  ...  stl%_max_opp_10_y  blk%_max_opp_10_y  \
# 0      0.511628  0.412698  ...             0.0657             0.1032
# 1      0.441860  0.396825  ...             0.0699             0.1072
# 2      0.418605  0.365079  ...             0.0389             0.0726
# 3      0.372093  0.412698  ...             0.0527             0.0770
# 4      0.186047  0.158730  ...             0.0574             0.0839
# ...         ...       ...  ...                ...                ...
# 19143  0.372093  0.301587  ...             0.0632             0.1177
# 19144  0.255814  0.238095  ...             0.0664             0.0859
# 19145  0.279070  0.269841  ...             0.0579             0.0835
# 19146  0.325581  0.269841  ...             0.0483             0.0724
# 19147  0.627907  0.507937  ...             0.0708             0.0947
#
#        tov%_max_opp_10_y  usg%_max_opp_10_y  ortg_max_opp_10_y  \
# 0               0.437212           0.126026           0.404739
# 1               0.380294           0.274359           0.270616
# 2               0.468868           0.124231           0.332227
# 3               0.504403           0.154359           0.344076
# 4               0.310377           0.128205           0.312796
# ...                  ...                ...                ...
# 19143           0.316352           0.111923           0.448815
# 19144           0.371593           0.160000           0.593839
# 19145           0.376415           0.158462           0.469668
# 19146           0.268658           0.168974           0.438389
# 19147           0.454298           0.169872           0.402844
#
#        drtg_max_opp_10_y  total_opp_10_y  home_opp_10_y  team_opp_next_y  \
# 0               0.408235        0.398214            0.2              TOR
# 1               0.478824        0.286607            0.6              SAC
# 2               0.407059        0.343750            0.5              ORL
# 3               0.384706        0.296429            0.7              CLE
# 4               0.410588        0.328571            0.5              PHI
# ...                  ...             ...            ...              ...
# 19143           0.620000        0.460714            0.8              POR
# 19144           0.604706        0.325000            0.4              BRK
# 19145           0.574118        0.469643            0.3              BOS
# 19146           0.536471        0.427679            0.6              PHO
# 19147           0.552941        0.486607            0.1              LAC
#
#        team_y
# 0         SAC
# 1         TOR
# 2         MIN
# 3         DET
# 4         DAL
# ...       ...
# 19143     OKC
# 19144     NYK
# 19145     DAL
# 19146     CHI
# 19147     LAL
#
# [19148 rows x 422 columns]

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next", "season", "won"]]
# Out:
#       team_x team_opp_next_x team_y team_opp_next_y   date_next  season    won
# 0        TOR             SAC    SAC             TOR  2015-11-15    2016   True
# 1        SAC             TOR    TOR             SAC  2015-11-15    2016   True
# 2        ORL             MIN    MIN             ORL  2015-11-18    2016  False
# 3        CLE             DET    DET             CLE  2015-11-17    2016  False
# 4        PHI             DAL    DAL             PHI  2015-11-16    2016  False
# ...      ...             ...    ...             ...         ...     ...    ...
# 19143    POR             OKC    OKC             POR  2024-01-23    2024  False
# 19144    BRK             NYK    NYK             BRK  2024-01-23    2024  False
# 19145    BOS             DAL    DAL             BOS  2024-01-22    2024   True
# 19146    PHO             CHI    CHI             PHO  2024-01-22    2024   True
# 19147    LAC             LAL    LAL             LAC  2024-01-23    2024   True
#
# [19148 rows x 7 columns]

# %%
full
# Out:
#         mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0   0.0  0.326087  0.250000  0.413876  0.310345  0.257576  0.509501
# 1      0.0   0.0  0.456522  0.500000  0.375598  0.379310  0.348485  0.483373
# 2      0.0   0.0  0.413043  0.397059  0.401914  0.137931  0.212121  0.263658
# 3      0.5   0.5  0.391304  0.455882  0.330144  0.482759  0.515152  0.437055
# 4      0.0   0.0  0.304348  0.323529  0.318182  0.275862  0.272727  0.432304
# ...    ...   ...       ...       ...       ...       ...       ...       ...
# 19143  0.0   0.0  0.500000  0.441176  0.473684  0.310345  0.378788  0.368171
# 19144  0.0   0.0  0.543478  0.441176  0.526316  0.482759  0.530303  0.426366
# 19145  0.0   0.0  0.521739  0.558824  0.406699  0.586207  0.651515  0.429929
# 19146  0.0   0.0  0.608696  0.323529  0.727273  0.275862  0.318182  0.380048
# 19147  0.0   0.0  0.500000  0.338235  0.566986  0.448276  0.333333  0.593824
#
#              ft       fta  ...  stl%_max_opp_10_y  blk%_max_opp_10_y  \
# 0      0.511628  0.412698  ...             0.0657             0.1032
# 1      0.441860  0.396825  ...             0.0699             0.1072
# 2      0.418605  0.365079  ...             0.0389             0.0726
# 3      0.372093  0.412698  ...             0.0527             0.0770
# 4      0.186047  0.158730  ...             0.0574             0.0839
# ...         ...       ...  ...                ...                ...
# 19143  0.372093  0.301587  ...             0.0632             0.1177
# 19144  0.255814  0.238095  ...             0.0664             0.0859
# 19145  0.279070  0.269841  ...             0.0579             0.0835
# 19146  0.325581  0.269841  ...             0.0483             0.0724
# 19147  0.627907  0.507937  ...             0.0708             0.0947
#
#        tov%_max_opp_10_y  usg%_max_opp_10_y  ortg_max_opp_10_y  \
# 0               0.437212           0.126026           0.404739
# 1               0.380294           0.274359           0.270616
# 2               0.468868           0.124231           0.332227
# 3               0.504403           0.154359           0.344076
# 4               0.310377           0.128205           0.312796
# ...                  ...                ...                ...
# 19143           0.316352           0.111923           0.448815
# 19144           0.371593           0.160000           0.593839
# 19145           0.376415           0.158462           0.469668
# 19146           0.268658           0.168974           0.438389
# 19147           0.454298           0.169872           0.402844
#
#        drtg_max_opp_10_y  total_opp_10_y  home_opp_10_y  team_opp_next_y  \
# 0               0.408235        0.398214            0.2              TOR
# 1               0.478824        0.286607            0.6              SAC
# 2               0.407059        0.343750            0.5              ORL
# 3               0.384706        0.296429            0.7              CLE
# 4               0.410588        0.328571            0.5              PHI
# ...                  ...             ...            ...              ...
# 19143           0.620000        0.460714            0.8              POR
# 19144           0.604706        0.325000            0.4              BRK
# 19145           0.574118        0.469643            0.3              BOS
# 19146           0.536471        0.427679            0.6              PHO
# 19147           0.552941        0.486607            0.1              LAC
#
#        team_y
# 0         SAC
# 1         TOR
# 2         MIN
# 3         DET
# 4         DAL
# ...       ...
# 19143     OKC
# 19144     NYK
# 19145     DAL
# 19146     CHI
# 19147     LAL
#
# [19148 rows x 422 columns]

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns + ["won"]

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]

# %%
predictors = list(selected_columns[sfs.get_support()])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 predictors = list(selected_columns[sfs.get_support()])
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:5196, in Index.__getitem__(self, key)
#    5193     else:
#    5194         key = np.asarray(key, dtype=bool)
# -> 5196 result = getitem(key)
#    5197 # Because we ruled out integer above, we always get an arraylike here
#    5198 if result.ndim > 1:
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 412 but corresponding boolean dimension is 137

# %%
predictors
# Out:
# ['fga',
#  'fta',
#  'ft%',
#  'ftr',
#  'trb%',
#  'usg%',
#  'ft_max',
#  'drb%_max',
#  'tov%_max',
#  'usg%_max',
#  'fg%_opp',
#  '3p%_opp',
#  'ft%_opp',
#  'orb_opp',
#  'pf_opp',
#  'ftr_opp',
#  'trb%_opp',
#  'ast%_opp',
#  'blk%_opp',
#  'usg%_opp',
#  'ft%_max_opp',
#  'orb_max_opp',
#  'trb_max_opp',
#  'stl_max_opp',
#  'drb%_max_opp',
#  'ast%_max_opp',
#  'stl%_max_opp',
#  'blk%_max_opp',
#  'tov%_max_opp',
#  'usg%_max_opp']

# %%
predictions = backtest(full, rr, predictors)

# %%
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5409439568792758

# %%
predictions
# Out:
#        actual  prediction
# 4677        1           0
# 4678        1           0
# 4679        1           1
# 4680        1           0
# 4681        1           1
# ...       ...         ...
# 19143       0           0
# 19144       0           0
# 19145       1           1
# 19146       1           1
# 19147       1           1
#
# [14471 rows x 2 columns]
